# %% [markdown]
# <H1>Analyzing Movie Review Sentiment for Classification Purposes</H1>

# %% [markdown]
# <H2>Summary</H2>
# The project is to analyze sentiment from movie review text, to classify it on a zero to four scale (0,1,2,3,4) from most negative to most postive.  The usefulness of sentiment classification extends to more than just parsing movie reviews and perhaps being able to aggregate and score them ala Metacritic or Rotten Tomatoes.  One example of the extended usefulness is that it holds use for political analysis, both for political statements of politicans, and commentary by the publie (e.g., twitter responses).  Another application is it useful for commercial companies to analyze what people are saying about their products.  Or it could be used by historians to analyze sentiment of text for a given time period to help judge what people thought in a given time period.  The potential uses are endless.
#
# The original thought for this research was to use the libraries from the NLTK to work on the classification problem.  Unfortunately the NTLK libraries are not set up to utilize multi-core processers and were exceptionally slow at classifying. In fact the classifier seemed to follow some sort of exponential growth on time, for example 3000 lines in the training set took about a minute, but 10000 took around <b>12</b> minutes.  Anyhow, the below is the start of the classification tried before given up and moving to use mostly SciKit libraries which take advantage of multi processing and allowed analysis to proceed much quicker.  That research is in the file labeled 'V2'.
#
# The source of the research was a Kaggle competition (closed now) were text from movie reviews were classified to use as a training set.  The location of the source is <A>https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews/</a>
#
# The training file for the work was structured like the following:
#
#     PhraseId	SentenceId	Phrase	Sentiment
# <ul style="list-style-type:none">
# <li>1	1	A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .	1 </li>
# <li>2	1	A series of escapades demonstrating the adage that what is good for the goose	2</li>
# <li>3	1	A series	2</li>
# <li>4	1	A	2</li>
# <li>5	1	series	2</li>
# <li>6	1	of escapades demonstrating the adage that what is good for the goose	2</li>
# </ul>
#
# The test file provided was the same except the sentiment classifier was not provided.

# %% [markdown]
# <H2>Set-up</H2>
# Import libraries and load the file.  Shuffle for training.

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
import pandas as pd
from sklearn.utils import shuffle
import time

lines=[]
dfTxt = pd.read_csv('moviesentiment/train.tsv', sep = '\t')
    
l = dfTxt.Phrase
l  = [l.split() for l in l]  #make each sentence a series of word tuples
lines = [(l[i], dfTxt.Sentiment[i]) for i in range(0,len(l))]

# we don't know the state of the imported data...shuffle to make sure it is random
lines = shuffle(lines, random_state=42)

# %% [markdown]
# <H2>Analytical Pipeline</H2>
# Mark words as negative after a negative phrase.  I.e.:
#
#     "He was not a happy person"
#
# would be transformed into:
#
#     "He was not a_neg happy_neg person_neg"
#
# Create unigram feature matrix of words and frequencies.  Note in working with this the min_freq was played with to speed up processing, but overall it was still very slow.

# %%
def sentimentPipeLine(lines):
    sentimAnalyzer = SentimentAnalyzer()
    all_words_neg = sentimAnalyzer.all_words([mark_negation(line) for line in lines])
    unigramFeats = sentimAnalyzer.unigram_word_feats(all_words_neg, min_freq=4)
    sentimAnalyzer.add_feat_extractor(extract_unigram_feats, unigrams=unigramFeats)
    return(sentimAnalyzer)

# %% [markdown]
# <H2>Create Method to Classify</H2>
# This runs the pipeline above, then "applies features" to a trainSet and testSet of data, trains it on the trainSet and then evaluates both the train and the test sets to see how well they have performed.

# %%
def runClassification(lines, size):
    trainLines = lines[:size]
    testLines = lines[size:size+200]
    startTime = time.time()        
    sentimAnalyzer = sentimentPipeLine(trainLines)     
    trainSet = sentimAnalyzer.apply_features(trainLines)
    testSet = sentimAnalyzer.apply_features(testLines)    
    trainer = NaiveBayesClassifier.train;
    classifier = sentimAnalyzer.train(trainer, trainSet)    
    
    evaluated = sentimAnalyzer.evaluate(trainSet)
    endTime = time.time()    
    print 'Time to train and evaluate: ' + str(endTime - startTime)    
    print 'TrainSetResults'
    for key,value in sorted(evaluated.items()):
        print('{0}: {1}'.format(key, value))

    print 'TestSet Results'
    
    evaluated = sentimAnalyzer.evaluate(testSet)
    for key,value in sorted(evaluated.items()):
        print('{0}: {1}'.format(key, value))

# %% [markdown]
# <H2>Run Classifier</H2>
# Initial results are poor, but we only ran 3000 lines when training.   More lines would improve, but b/c of slow performance we will leave it at 3000 and run more expansively later.

# %%
runClassification(lines,3000)
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# Time to train and evaluate: 53.3659999371
# TrainSetResults
# Accuracy: 0.617
# F-measure [0]: 0.404255319149
# F-measure [1]: 0.45549132948
# F-measure [2]: 0.738652382295
# F-measure [3]: 0.427010923535
# F-measure [4]: 0.481605351171
# Precision [0]: 0.398601398601
# Precision [1]: 0.567723342939
# Precision [2]: 0.646913580247
# Precision [3]: 0.576407506702
# Precision [4]: 0.642857142857
# Recall [0]: 0.410071942446
# Recall [1]: 0.380308880309
# Recall [2]: 0.860709592641
# Recall [3]: 0.339116719243
# Recall [4]: 0.385026737968
# TestSet Results
# Evaluating NaiveBayesClassifier results...
# Accuracy: 0.485
# F-measure [0]: 0.315789473684
# F-measure [1]: 0.204081632653
# F-measure [2]: 0.618644067797
# F-measure [3]: 0.268656716418
# F-measure [4]: 0.48275862069
# Precision [0]: 0.375
# Precision [1]: 0.357142857143
# Precision [2]: 0.493243243243
# Precision [3]: 0.45
# Precision [4]: 0.7
# Recall [0]: 0.272727272727
# Recall [1]: 0.142857142857
# Recall [2]: 0.829545454545
# Recall [3]: 0.191489361702
# Recall [4]: 0.368421052632

# %% [markdown]
# <H2>Standardizing Case</H2>
# We lowercased all words to normalize them, the hope was to improve performance by reducing the number of words in the feature sets.  It helped very minimally with speed.

# %%
#lowercase string in lines
lines = [([s.lower() for s in line[0]],line[1]) for line in lines]
runClassification(lines,3000)
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# Time to train and evaluate: 52.3480000496
# TrainSetResults
# Accuracy: 0.614333333333
# F-measure [0]: 0.404181184669
# F-measure [1]: 0.456546929316
# F-measure [2]: 0.73556744579
# F-measure [3]: 0.419678714859
# F-measure [4]: 0.481848184818
# Precision [0]: 0.391891891892
# Precision [1]: 0.571014492754
# Precision [2]: 0.643666830951
# Precision [3]: 0.577348066298
# Precision [4]: 0.629310344828
# Recall [0]: 0.41726618705
# Recall [1]: 0.380308880309
# Recall [2]: 0.858081471748
# Recall [3]: 0.329652996845
# Recall [4]: 0.390374331551
# TestSet Results
# Evaluating NaiveBayesClassifier results...
# Accuracy: 0.47
# F-measure [0]: 0.3
# F-measure [1]: 0.196078431373
# F-measure [2]: 0.610169491525
# F-measure [3]: 0.25
# F-measure [4]: 0.413793103448
# Precision [0]: 0.333333333333
# Precision [1]: 0.3125
# Precision [2]: 0.486486486486
# Precision [3]: 0.470588235294
# Precision [4]: 0.6
# Recall [0]: 0.272727272727
# Recall [1]: 0.142857142857
# Recall [2]: 0.818181818182
# Recall [3]: 0.170212765957
# Recall [4]: 0.315789473684
# [(["'s", 'as', 'sorry'], 2),
#  (['romantic',
#    'comedy',
#    'and',
#    'dogme',
#    '95',
#    'filmmaking',
#    'may',
#    'seem',
#    'odd',
#    'bedfellows',
#    ',',
#    'but',
#    'they',
#    'turn',
#    'out',
#    'to',
#    'be',
#    'delightfully',
#    'compatible',
#    'here'],
#   4),
#  (['of', 'these', 'days'], 2),
#  (['flinch', 'from', 'its', 'unsettling', 'prognosis'], 2),
#  (['are', 'clinically', 'depressed'], 1),
#  (['just',
#    'too',
#    'silly',
#    'and',
#    'sophomoric',
#    'to',
#    'ensnare',
#    'its',
#    'target',
#    'audience',
#    '.'],
#   1),
#  (['thoughtful', 'without', 'having', 'much', 'dramatic', 'impact'], 1),
#  (['manage', 'to', 'be', 'spectacularly', 'outrageous', '.'], 3),
#  (['hunk'], 4),
#  (['forgotten', '10', 'minutes'], 1),
#  (['the',
#    'slapstick',
#    'is',
#    'labored',
#    ',',
#    'and',
#    'the',
#    'bigger',
#    'setpieces',
#    'flat',
#    '.'],
#   0),
#  (['fusty'], 2),
#  (['disguise',
#    'the',
#    'fact',
#    'that',
#    'the',
#    'new',
#    'film',
#    'is',
#    'a',
#    'lame',
#    'kiddie',
#    'flick',
#    'and',
#    'that',
#    'carvey',
#    "'s",
#    'considerable',
#    'talents',
#    'are',
#    'wasted',
#    'in',
#    'it'],
#   0),
#  (['eclipses'], 3),
#  (['lack-of-attention', 'span'], 1),
#  (["'s", 'a', 'masterpeice', '.'], 4),
#  (['driven'], 2),
#  (['a', 'reluctant', ',', 'irresponsible', 'man', 'and'], 1),
#  ([',', 'aching', 'sadness'], 2),
#  (['despair', 'or'], 2),
#  (['enough', 'to', 'keep', 'us'], 2),
#  (['a', 'more', 'generic', 'effort', 'in', 'the', 'genre'], 2),
#  (['an', 'aging', 'filmmaker'], 2),
#  (['to', 'ride', 'a', 'russian', 'rocket'], 2),
#  (['treats', 'his', 'audience'], 2),
#  (['elderly'], 2),
#  (['spans', 'time', 'and'], 2),
#  (['for',
#    'this',
#    'sort',
#    'of',
#    'thing',
#    'to',
#    'work',
#    ',',
#    'we',
#    'need',
#    'agile',
#    'performers'],
#   2),
#  (['cheap', 'shocks'], 1),
#  (['is', 'amiss', 'in', 'the', 'world', '.'], 1),
#  (['shadows',
#    'heidi',
#    "'s",
#    'trip',
#    'back',
#    'to',
#    'vietnam',
#    'and',
#    'the',
#    'city'],
#   2),
#  (['director',
#    'hoffman',
#    ',',
#    'his',
#    'writer',
#    'and',
#    'kline',
#    "'s",
#    'agent',
#    'should',
#    'serve',
#    'detention'],
#   0),
#  (['brogue'], 2),
#  (['of', 'dreams', 'and', 'aspirations'], 2),
#  (['technically', 'superb', 'film'], 3),
#  (['head', 'off'], 2),
#  (['used', 'manhattan', "'s", 'architecture'], 2),
#  (['an', 'undeniably', 'moving', 'film', 'to', 'experience'], 3),
#  (['might',
#    'have',
#    'been',
#    'acceptable',
#    'on',
#    'the',
#    'printed',
#    'page',
#    'of',
#    'iles',
#    "'",
#    'book'],
#   2),
#  (['a',
#    'lot',
#    'of',
#    'fun',
#    ',',
#    'with',
#    'an',
#    'undeniable',
#    'energy',
#    'sparked',
#    'by',
#    'two',
#    'actresses',
#    'in',
#    'their',
#    '50s',
#    'working',
#    'at',
#    'the',
#    'peak',
#    'of',
#    'their',
#    'powers',
#    '.'],
#   4),
#  (['have',
#    'the',
#    'worthy',
#    'successor',
#    'to',
#    'a',
#    'better',
#    'tomorrow',
#    'and',
#    'the',
#    'killer',
#    'which',
#    'they',
#    'have',
#    'been',
#    'patiently',
#    'waiting',
#    'for'],
#   4),
#  (['if',
#    'all',
#    'of',
#    'eight',
#    'legged',
#    'freaks',
#    'was',
#    'as',
#    'entertaining',
#    'as',
#    'the',
#    'final',
#    'hour'],
#   2),
#  (['play', 'one', 'lewd', 'scene'], 2),
#  (['mad',
#    'love',
#    'does',
#    "n't",
#    'galvanize',
#    'its',
#    'outrage',
#    'the',
#    'way',
#    ','],
#   1),
#  (['you', 'can', 'find', 'humor'], 3),
#  (['the',
#    'most',
#    'ravaging',
#    ',',
#    'gut-wrenching',
#    ',',
#    'frightening',
#    'war',
#    'scenes',
#    'since',
#    '``',
#    'saving',
#    'private',
#    'ryan',
#    "''"],
#   3),
#  (['adds',
#    'up',
#    'to',
#    'big',
#    'box',
#    'office',
#    'bucks',
#    'all',
#    'but',
#    'guaranteed'],
#   3),
#  (['whose', 'seeming'], 2),
#  (['`'], 2),
#  (['did',
#    'we',
#    'really',
#    'need',
#    'a',
#    'remake',
#    'of',
#    '``',
#    'charade',
#    '?',
#    "''"],
#   1),
#  (['of', 'convenience'], 2),
#  (['achieve',
#    'a',
#    'shock-you-into-laughter',
#    'intensity',
#    'of',
#    'almost',
#    'dadaist',
#    'proportions'],
#   3),
#  (['precious', 'little', 'substance', 'in', 'birthday', 'girl'], 1),
#  (['foster', 'and', 'whitaker'], 2),
#  (['as', 'they', 'do', 'in', 'this', 'marvelous', 'film'], 4),
#  (['unclear'], 1),
#  (['in', 'cheek', 'in', 'the', 'film'], 2),
#  (['meaty', 'subject'], 3),
#  (['of', 'greatest-hits', 'reel'], 3),
#  (['an', 'obvious', 'copy', 'of', 'one', 'of', 'the', 'best', 'films'], 2),
#  (['the', 'way', 'home'], 3),
#  (['seeming'], 2),
#  (['inject', 'some', 'real', 'vitality', 'and', 'even', 'art'], 3),
#  (['is', 'sort', 'of', 'a', 'minimalist', 'beauty', 'and', 'the', 'beast'], 2),
#  (['it',
#    'just',
#    'goes',
#    'to',
#    'show',
#    'that',
#    'if',
#    'you',
#    'give',
#    'a',
#    'filmmaker',
#    'an',
#    'unlimited',
#    'amount',
#    'of',
#    'phony',
#    'blood',
#    ',',
#    'nothing',
#    'good',
#    'can',
#    'happen'],
#   1),
#  (['do', "n't", 'bother', '.'], 2),
#  (['can', 'be', 'said', 'about', 'stealing', 'harvard'], 2),
#  (['sometimes',
#    'makes',
#    'less',
#    'sense',
#    'than',
#    'the',
#    'bruckheimeresque',
#    'american',
#    'action',
#    'flicks',
#    'it',
#    'emulates',
#    '.'],
#   1),
#  (['what', 'a', 'reckless'], 1),
#  (['what', 'they', 'did'], 2),
#  (['engaging', 'charisma'], 3),
#  (['diesel', "'s"], 2),
#  (['bad', 'mannered'], 1),
#  (['operas', '.'], 2),
#  (['half', 'an', 'hour', 'of', 'car', 'chases'], 2),
#  ([',',
#    'barbershop',
#    'gets',
#    'its',
#    'greatest',
#    'play',
#    'from',
#    'the',
#    'timeless',
#    'spectacle',
#    'of',
#    'people',
#    'really',
#    'talking',
#    'to',
#    'each',
#    'other',
#    '.'],
#   3),
#  (['predisposed', 'to', 'like', 'it'], 3),
#  (['porky', "'s"], 2),
#  (['statham', 'can', 'move', 'beyond', 'the', 'crime-land', 'action', 'genre'],
#   2),
#  (["'ll", 'enjoy', 'the', 'hot', 'chick'], 2),
#  (['the', 'bread', ',', 'my', 'sweet'], 2),
#  (['is',
#    'less',
#    'a',
#    'documentary',
#    'and',
#    'more',
#    'propaganda',
#    'by',
#    'way',
#    'of',
#    'a',
#    'valentine',
#    'sealed',
#    'with',
#    'a',
#    'kiss'],
#   1),
#  (['her', 'tragedies'], 1),
#  (['under', 'the', 'skin', 'of', 'her', 'characters'], 3),
#  (['must',
#    'be',
#    'given',
#    'to',
#    'the',
#    'water-camera',
#    'operating',
#    'team',
#    'of',
#    'don',
#    'king',
#    ',',
#    'sonny',
#    'miller',
#    ',',
#    'and',
#    'michael',
#    'stewart'],
#   2),
#  (['his', 'prelude'], 2),
#  (['that', 'he', "'s", 'witnessed'], 2),
#  (['drown', 'out', 'the', 'tinny', 'self-righteousness', 'of', 'his', 'voice'],
#   1),
#  (['the', 'interviews', 'that', 'follow'], 2),
#  ([',', 'then', 'you', "'ll", 'enjoy', 'the', 'hot', 'chick', '.'], 4),
#  (['crush', 'departs', 'from', 'the', '4w', 'formula'], 2),
#  (['bubba', 'ho-tep', "'s", 'clearly', 'evident', 'quality'], 3),
#  (['tadpole',
#    "'",
#    'was',
#    'one',
#    'of',
#    'the',
#    'films',
#    'so',
#    'declared',
#    'this',
#    'year',
#    ',',
#    'but',
#    'it',
#    "'s",
#    'really',
#    'more',
#    'of',
#    'the',
#    'next',
#    'pretty',
#    'good',
#    'thing'],
#   2),
#  (['being', 'there', 'when', 'the', 'rope', 'snaps'], 2),
#  (['female', 'friendship', 'that', 'men', 'can', 'embrace', 'and', 'women'],
#   2),
#  (['could',
#    'just',
#    'as',
#    'well',
#    'be',
#    'addressing',
#    'the',
#    'turn',
#    'of',
#    'the',
#    '20th',
#    'century',
#    'into',
#    'the',
#    '21st'],
#   2),
#  (['diaz'], 2),
#  (['-lrb-',
#    'denis',
#    '-rrb-',
#    'accomplishes',
#    'in',
#    'his',
#    'chilling',
#    ',',
#    'unnerving',
#    'film'],
#   3),
#  (['some', 'very', 'funny', 'sequences'], 3),
#  (['it',
#    'forces',
#    'you',
#    'to',
#    'watch',
#    'people',
#    'doing',
#    'unpleasant',
#    'things',
#    'to',
#    'each',
#    'other',
#    'and',
#    'themselves',
#    ',',
#    'and',
#    'it',
#    'maintains',
#    'a',
#    'cool',
#    'distance',
#    'from',
#    'its',
#    'material',
#    'that',
#    'is',
#    'deliberately',
#    'unsettling',
#    '.'],
#   1),
#  (['bias'], 1),
#  ([',',
#    'the',
#    'film',
#    'is',
#    'blazingly',
#    'alive',
#    'and',
#    'admirable',
#    'on',
#    'many',
#    'levels',
#    '.'],
#   4),
#  (['invested',
#    'in',
#    'undergraduate',
#    'doubling',
#    'subtexts',
#    'and',
#    'ridiculous',
#    'stabs'],
#   0),
#  (['this', 'version', 'of', 'h.g.', 'wells', "'", 'time', 'machine'], 2),
#  (['multiple', 'stories'], 2),
#  (['loosely',
#    'speaking',
#    ',',
#    'we',
#    "'re",
#    'in',
#    'all',
#    'of',
#    'me',
#    'territory',
#    'again',
#    ',',
#    'and',
#    ','],
#   2),
#  (['drive', 'you', 'crazy'], 2),
#  (['to', 'the', 'experiences', 'of', 'most', 'battered', 'women'], 2),
#  (['dvd', 'rental'], 2),
#  (['orlando', 'jones'], 2),
#  (['carefully',
#    'delineate',
#    'the',
#    'cost',
#    'of',
#    'the',
#    'inevitable',
#    'conflicts',
#    'between',
#    'human',
#    'urges',
#    'and',
#    'an',
#    'institution',
#    'concerned',
#    'with',
#    'self-preservation'],
#   2),
#  ([',',
#    'actor',
#    'raymond',
#    'j.',
#    'barry',
#    'is',
#    'perfectly',
#    'creepy',
#    'and',
#    'believable',
#    '.'],
#   4),
#  (['van'], 2),
#  (['littered', 'with', 'celluloid', 'garbage'], 1),
#  (['was',
#    'more',
#    'fun',
#    'when',
#    'his',
#    'characters',
#    'were',
#    'torturing',
#    'each',
#    'other',
#    'psychologically',
#    'and',
#    'talking',
#    'about',
#    'their',
#    'genitals',
#    'in',
#    'public'],
#   1),
#  (['condensed'], 2),
#  (['violent',
#    'and',
#    'a',
#    'bit',
#    'exploitative',
#    'but',
#    'also',
#    'nicely',
#    'done',
#    ',',
#    'morally',
#    'alert',
#    'and',
#    'street-smart'],
#   3),
#  (['sufficient', 'distance'], 2),
#  (['of', 'all', 'those', 'famous', 'moments'], 3),
#  (['the', 'occasional', 'belly', 'laugh'], 3),
#  (['--',
#    'more',
#    'revealing',
#    ',',
#    'more',
#    'emotional',
#    'and',
#    'more',
#    'surprising',
#    '--'],
#   4),
#  (['the', 'words', 'of', 'nijinsky', "'s", 'diaries'], 2),
#  (['and', 'plot', 'threads'], 2),
#  (['itself', ',', 'a', 'playful', 'spirit', 'and', 'a', 'game', 'cast'], 3),
#  (['peploe'], 2),
#  (['go',
#    'in',
#    'knowing',
#    'full',
#    'well',
#    'what',
#    "'s",
#    'going',
#    'to',
#    'happen'],
#   2),
#  (['gainsbourg'], 2),
#  (['of', 'class'], 2),
#  (['wearing', 'the', 'somewhat', 'cumbersome', '3d', 'goggles'], 1),
#  (['the', 'preteen', 'boy', 'in', 'mind'], 2),
#  (['racial', 'tension'], 1),
#  (['clocks'], 2),
#  (['...',
#    'a',
#    'hokey',
#    'piece',
#    'of',
#    'nonsense',
#    'that',
#    'tries',
#    'too',
#    'hard',
#    'to',
#    'be',
#    'emotional',
#    '.'],
#   0),
#  (['of', 'a', 'lovingly', 'rendered', 'coffee', 'table', 'book'], 3),
#  (['through', 'everyday', 'events'], 2),
#  (['at',
#    'once',
#    'visceral',
#    'and',
#    'spiritual',
#    ',',
#    'wonderfully',
#    'vulgar',
#    'and',
#    'sublimely',
#    'lofty',
#    '--',
#    'and',
#    'as',
#    'emotionally',
#    'grand'],
#   4),
#  (['means', 'check', 'it', 'out', '.'], 3),
#  (['maintains',
#    'suspense',
#    'on',
#    'different',
#    'levels',
#    'throughout',
#    'a',
#    'film',
#    'that',
#    'is',
#    'both',
#    'gripping',
#    'and',
#    'compelling'],
#   3),
#  (['it',
#    'shares',
#    'the',
#    'first',
#    'two',
#    'films',
#    "'",
#    'loose-jointed',
#    'structure',
#    ',',
#    'but'],
#   1),
#  (['enjoyable', 'in', 'its', 'own', 'right'], 3),
#  (['a', 'little', 'more', 'attention', 'paid', 'to', 'the', 'animation'], 3),
#  (['greasy', 'little', 'vidgame', 'pit'], 1),
#  (['the', 'same', 'sort'], 2),
#  (['america', ',', 'history'], 3),
#  (['insightful', 'moments'], 3),
#  (['the', 'grandeur', 'of', 'the', 'best', 'next', 'generation', 'episodes'],
#   3),
#  (['your', 'introduction'], 2),
#  (['most',
#    'of',
#    'the',
#    'information',
#    'has',
#    'already',
#    'appeared',
#    'in',
#    'one',
#    'forum',
#    'or',
#    'another',
#    'and'],
#   2),
#  (['the', 'inspiration'], 3),
#  (['shoot', 'a', 'lot', 'of', 'bullets'], 2),
#  (['occasionally', 'funny', ',', 'sometimes', 'inspiring', ','], 3),
#  (['wounded'], 2),
#  (['\\*',
#    'a',
#    '\\*',
#    's',
#    '\\*',
#    'h',
#    "''",
#    'only',
#    'this',
#    'time',
#    'from',
#    'an',
#    'asian',
#    'perspective',
#    '.'],
#   2),
#  (['an',
#    'acceptable',
#    'way',
#    'to',
#    'pass',
#    'a',
#    'little',
#    'over',
#    'an',
#    'hour',
#    'with',
#    'moviegoers',
#    'ages',
#    '8-10',
#    ',',
#    'but',
#    'it',
#    "'s",
#    'unlikely',
#    'to',
#    'inspire',
#    'anything',
#    'more',
#    'than',
#    'a',
#    'visit',
#    'to',
#    'mcdonald',
#    "'s",
#    ',',
#    'let',
#    'alone',
#    'some',
#    'savvy',
#    'street',
#    'activism',
#    '.'],
#   1),
#  (['overwhelming', 'pleasure'], 4),
#  (['the',
#    'final',
#    'effect',
#    'is',
#    'like',
#    'having',
#    'two',
#    'guys',
#    'yelling',
#    'in',
#    'your',
#    'face',
#    'for',
#    'two',
#    'hours',
#    '.'],
#   0),
#  (['if',
#    'there',
#    'ai',
#    "n't",
#    'none',
#    ',',
#    'you',
#    'have',
#    'a',
#    'problem',
#    '.'],
#   2),
#  (['need',
#    'all',
#    'the',
#    'luck',
#    'they',
#    'can',
#    'muster',
#    'just',
#    'figuring',
#    'out',
#    'who',
#    "'s",
#    'who',
#    'in',
#    'this',
#    'pretentious',
#    'mess'],
#   0),
#  (['a', 'millisecond', 'of', 'thought'], 2),
#  (['must',
#    'have',
#    'seemed',
#    'to',
#    'frida',
#    'kahlo',
#    'as',
#    'if',
#    'her',
#    'life',
#    'did',
#    ',',
#    'too'],
#   2),
#  (['argue',
#    'that',
#    'the',
#    'debate',
#    'it',
#    'joins',
#    'is',
#    'a',
#    'necessary',
#    'and',
#    'timely',
#    'one'],
#   2),
#  (['rich', 'and'], 3),
#  (['that', 'proves', 'you'], 3),
#  (['make', 'you', 'feel', 'like', 'you', 'owe', 'her', 'big-time'], 2),
#  (['spare', 'yet', 'audacious'], 2),
#  (['portrays', ',', 'tiresomely'], 1),
#  (['end', 'this', 'flawed', ',', 'dazzling', 'series'], 1),
#  (['a', 'taunt', '-'], 2),
#  (['be', 'thinking', 'of', '51', 'ways', 'to', 'leave', 'this', 'loser'], 0),
#  (['strange', ',', 'fleeting', 'brew'], 3),
#  (['there',
#    'are',
#    'cheesy',
#    'backdrops',
#    ',',
#    'ridiculous',
#    'action',
#    'sequences',
#    ',',
#    'and',
#    'many',
#    'tired',
#    'jokes',
#    'about',
#    'men',
#    'in',
#    'heels',
#    '.'],
#   0),
#  (['been', 'as', 'a', 'film'], 2),
#  (['rough'], 1),
#  (['to',
#    'share',
#    'his',
#    'impressions',
#    'of',
#    'life',
#    'and',
#    'loss',
#    'and',
#    'time',
#    'and',
#    'art',
#    'with',
#    'us'],
#   3),
#  (['provocative', 'material'], 3),
#  (['about', 'high', 'crimes'], 2),
#  ([',', 'they', 'finally', 'feel', 'absolutely', 'earned'], 3),
#  (['the', 'price', 'of', 'admission', 'for', 'the', 'ridicule', 'factor'], 0),
#  (['like',
#    'a',
#    'rather',
#    'unbelievable',
#    'love',
#    'interest',
#    'and',
#    'a',
#    'meandering',
#    'ending',
#    '--'],
#   0),
#  (['there', "'s", 'nothing', 'remotely', 'topical', 'or', 'sexy', 'here', '.'],
#   1),
#  (['grind'], 2),
#  (['me', 'on', 'the', 'santa', 'clause', '2'], 2),
#  (['acting', 'exercise'], 2),
#  (['trier'], 2),
#  (['rohmer'], 2),
#  (['will', 'capture', 'the', 'minds', 'and', 'hearts', 'of', 'many'], 3),
#  (['has',
#    'no',
#    'respect',
#    'for',
#    'laws',
#    ',',
#    'political',
#    'correctness',
#    'or',
#    'common',
#    'decency'],
#   1),
#  (['your', 'dream'], 3),
#  (['a', 'work', 'of', 'deft', 'and', 'subtle', 'poetry'], 3),
#  (['makes',
#    'shanghai',
#    'ghetto',
#    'move',
#    'beyond',
#    'a',
#    'good',
#    ',',
#    'dry',
#    ',',
#    'reliable',
#    'textbook'],
#   3),
#  (['boredom',
#    'to',
#    'the',
#    'point',
#    'of',
#    'collapse',
#    ',',
#    'turning',
#    'into',
#    'a',
#    'black',
#    'hole',
#    'of',
#    'dullness'],
#   0),
#  (['rotoscope', 'animation'], 2),
#  (['imponderably', 'stilted', 'and'], 1),
#  (['this',
#    'is',
#    'an',
#    'exercise',
#    'not',
#    'in',
#    'biography',
#    'but',
#    'in',
#    'hero',
#    'worship',
#    '.'],
#   1),
#  (['like',
#    'a',
#    'glossy',
#    'melodrama',
#    'that',
#    'occasionally',
#    'verges',
#    'on',
#    'camp'],
#   2),
#  (['this',
#    'properly',
#    'intense',
#    ',',
#    'claustrophobic',
#    'tale',
#    'of',
#    'obsessive',
#    'love'],
#   4),
#  (['teens',
#    'are',
#    'looking',
#    'for',
#    'something',
#    'to',
#    'make',
#    'them',
#    'laugh'],
#   3),
#  (['the', 'rope', 'snaps'], 1),
#  (['iles'], 3),
#  (['do',
#    'all',
#    'three',
#    'quite',
#    'well',
#    ',',
#    'making',
#    'it',
#    'one',
#    'of',
#    'the',
#    'year',
#    "'s",
#    'most',
#    'enjoyable',
#    'releases'],
#   4),
#  (['you', "'ll", 'probably', 'love', 'it', '.'], 4),
#  (['director',
#    'kevin',
#    'bray',
#    'excels',
#    'in',
#    'breaking',
#    'glass',
#    'and',
#    'marking',
#    'off',
#    'the',
#    '``',
#    'miami',
#    'vice',
#    "''",
#    'checklist',
#    'of',
#    'power',
#    'boats',
#    ',',
#    'latin',
#    'music',
#    'and',
#    'dog',
#    'tracks',
#    '.'],
#   2),
#  (['to',
#    'treat',
#    'its',
#    'characters',
#    ',',
#    'weak',
#    'and',
#    'strong',
#    ',',
#    'as',
#    'fallible',
#    'human',
#    'beings',
#    ',',
#    'not',
#    'caricatures',
#    ',',
#    'and',
#    'to',
#    'carefully',
#    'delineate',
#    'the',
#    'cost',
#    'of',
#    'the',
#    'inevitable',
#    'conflicts',
#    'between',
#    'human',
#    'urges',
#    'and',
#    'an',
#    'institution',
#    'concerned',
#    'with',
#    'self-preservation'],
#   3),
#  (['likably'], 2),
#  (['historical', 'reality'], 2),
#  (['all', 'entertaining', 'enough'], 3),
#  (['is', 'a', 'masterpiece', '.'], 4),
#  (['14-year-old'], 2),
#  (['engaging', ','], 3),
#  (['a', 'therapy-dependent', 'flakeball'], 2),
#  (['five', 'hours', 'long'], 1),
#  (['fascinated',
#    'by',
#    'behan',
#    'but',
#    'leave',
#    'everyone',
#    'else',
#    'yawning',
#    'with',
#    'admiration',
#    '.'],
#   3),
#  (["'re", 'not', 'merely', 'watching', 'history'], 3),
#  (['crossroads'], 2),
#  (['to',
#    'the',
#    'gorgeous',
#    'locales',
#    'and',
#    'exceptional',
#    'lead',
#    'performances'],
#   3),
#  (['hilariously', ',', 'gloriously', 'alive', ','], 4),
#  (["'s", 'entertaining', 'enough', 'and', 'worth', 'a', 'look'], 3),
#  (['an', 'afterthought'], 2),
#  (['quiet', 'cadences'], 2),
#  (['should', 'be', 'seen', 'as', 'a', 'conversation', 'starter'], 2),
#  (['is', 'in', 'need', 'of', 'a', 'scented', 'bath'], 1),
#  (['flakeball'], 1),
#  (['without', 'shakespeare', "'s", 'eloquent', 'language'], 2),
#  (['than', 'a', 'rat', 'burger'], 2),
#  (['viva', 'le', 'resistance'], 3),
#  (['renowned'], 3),
#  (['give', 'the', 'movie', 'points'], 2),
#  (['the',
#    'plot',
#    'grows',
#    'thin',
#    'soon',
#    ',',
#    'and',
#    'you',
#    'find',
#    'yourself',
#    'praying',
#    'for',
#    'a',
#    'quick',
#    'resolution'],
#   1),
#  (['not', 'sophomoric'], 3),
#  (['light', 'the', 'candles'], 2),
#  (['appreciative'], 3),
#  (['very',
#    'compelling',
#    ',',
#    'sensitive',
#    ',',
#    'intelligent',
#    'and',
#    'almost',
#    'cohesive'],
#   3),
#  (['enough', 'insight', 'to', 'keep', 'it', 'from', 'being', 'simpleminded'],
#   3),
#  (['seems', 'so', 'larger', 'than', 'life', 'and', 'yet', 'so', 'fragile'], 3),
#  ([',',
#    'the',
#    'french-produced',
#    '``',
#    'read',
#    'my',
#    'lips',
#    "''",
#    'is',
#    'a',
#    'movie',
#    'that',
#    'understands',
#    'characters',
#    'must',
#    'come',
#    'first',
#    '.'],
#   3),
#  (["'30s", 'and', "'40s"], 2),
#  (['stop-and-start'], 2),
#  (['of', ':'], 2),
#  (['brutally', 'labored', 'and', 'unfunny', 'hokum'], 0),
#  (['the',
#    'direction',
#    'occasionally',
#    'rises',
#    'to',
#    'the',
#    'level',
#    'of',
#    'marginal',
#    'competence',
#    ',',
#    'but',
#    'for',
#    'most',
#    'of',
#    'the',
#    'film',
#    'it',
#    'is',
#    'hard',
#    'to',
#    'tell',
#    'who',
#    'is',
#    'chasing',
#    'who',
#    'or',
#    'why',
#    '.'],
#   1),
#  (['in', 'nostalgia'], 2),
#  (['twisty', 'yarn'], 2),
#  (['with',
#    'the',
#    'kind',
#    'of',
#    'social',
#    'texture',
#    'and',
#    'realism',
#    'that',
#    'would',
#    'be',
#    'foreign',
#    'in',
#    'american',
#    'teen',
#    'comedies'],
#   3),
#  (['to', 'the', 'mothman', 'prophecies'], 2),
#  (['never',
#    'bothers',
#    'to',
#    'hand',
#    'viewers',
#    'a',
#    'suitcase',
#    'full',
#    'of',
#    'easy',
#    'answers'],
#   2),
#  (['the',
#    'last',
#    'kiss',
#    'will',
#    'probably',
#    'never',
#    'achieve',
#    'the',
#    'popularity',
#    'of',
#    'my',
#    'big',
#    'fat',
#    'greek',
#    'wedding',
#    ',',
#    'but'],
#   1),
#  (['logical', 'loopholes'], 2),
#  (['dying', 'and', 'going'], 1),
#  (['charged', 'music', 'to', 'the', 'ears', 'of', 'cho', "'s", 'fans'], 3),
#  (['good',
#    'as',
#    'the',
#    'full',
#    'monty',
#    ',',
#    'but',
#    'a',
#    'really',
#    'strong',
#    'second',
#    'effort'],
#   3),
#  (['the',
#    'overcooked',
#    ',',
#    'ham-fisted',
#    'direction',
#    ',',
#    'which',
#    'has',
#    'all',
#    'the',
#    'actors',
#    'reaching',
#    'for',
#    'the',
#    'back',
#    'row'],
#   0),
#  (['the',
#    'bombastic',
#    'self-glorification',
#    'of',
#    'other',
#    'feel-good',
#    'fiascos',
#    'like',
#    'antwone',
#    'fisher',
#    'or',
#    'the',
#    'emperor',
#    "'s",
#    'club',
#    'any',
#    'time'],
#   3),
#  (['most', 'contemporary', 'adult', 'movies'], 2),
#  (['time', ',', 'money', 'and', 'celluloid'], 2),
#  (["'s",
#    'better',
#    'suited',
#    'for',
#    'the',
#    'history',
#    'or',
#    'biography',
#    'channel'],
#   2),
#  (['of', 'where', 'it', 'should', 'go'], 2),
#  (['flog',
#    'the',
#    'dead',
#    'horse',
#    'of',
#    'surprise',
#    'as',
#    'if',
#    'it',
#    'were',
#    'an',
#    'obligation'],
#   1),
#  (['impulsive'], 2),
#  (['have',
#    'easily',
#    'become',
#    'a',
#    'cold',
#    ',',
#    'calculated',
#    'exercise',
#    'in',
#    'postmodern',
#    'pastiche',
#    'winds',
#    'up',
#    'a',
#    'powerful',
#    'and',
#    'deeply',
#    'moving',
#    'example',
#    'of',
#    'melodramatic',
#    'moviemaking'],
#   3),
#  (['the', 'bod'], 2),
#  (['moulds', 'itself'], 2),
#  (['mgm'], 2),
#  (['denzel', 'washington', "'s", 'fine', 'performance'], 4),
#  (['moviemakers'], 2),
#  (['a', 'kind', ',', 'unapologetic', ',', 'sweetheart', 'of', 'a', 'movie'],
#   3),
#  (['most', 'accomplished', 'work'], 4),
#  (['his', 'colleagues'], 2),
#  (['napoleon', 'films'], 2),
#  (['being',
#    '``',
#    'in',
#    'the',
#    'mood',
#    "''",
#    'to',
#    'view',
#    'a',
#    'movie',
#    'as',
#    'harrowing',
#    'and',
#    'painful',
#    'as',
#    'the',
#    'grey',
#    'zone'],
#   1),
#  (['coming',
#    'back',
#    'to',
#    'the',
#    'achingly',
#    'unfunny',
#    'phonce',
#    'and',
#    'his',
#    'several',
#    'silly',
#    'subplots'],
#   1),
#  (['best', 'and', 'most', 'mature'], 4),
#  (['resolutions'], 2),
#  (['somewhere'], 2),
#  (['19', 'stays', 'afloat'], 2),
#  (['of', 'self-expression'], 2),
#  (['to',
#    'sober',
#    'us',
#    'up',
#    'with',
#    'the',
#    'transparent',
#    'attempts',
#    'at',
#    'moralizing'],
#   1),
#  (['inspiring', 'or'], 2),
#  (['a',
#    'highly',
#    'personal',
#    'look',
#    'at',
#    'the',
#    'effects',
#    'of',
#    'living',
#    'a',
#    'dysfunctionally',
#    'privileged',
#    'lifestyle',
#    ',',
#    'and'],
#   2),
#  (['of', 'room'], 2),
#  (['in',
#    'terms',
#    'of',
#    'the',
#    'low-grade',
#    'cheese',
#    'standards',
#    'on',
#    'which',
#    'it',
#    'operates'],
#   1),
#  (['hopeless', ',', 'unsatisfying', 'muddle'], 0),
#  (['is', 'seriously'], 2),
#  (['is', 'small'], 2),
#  (['the', 'self-destructiveness', 'of', 'many', 'young', 'people'], 1),
#  (['articulates', 'a', 'flood', 'of', 'emotion'], 2),
#  (['this', 'delicate', 'coming-of-age', 'tale'], 3),
#  (['the', 'wonders', 'and', 'worries'], 2),
#  (['an',
#    'underachiever',
#    ',',
#    'a',
#    'psychological',
#    'mystery',
#    'that',
#    'takes',
#    'its',
#    'sweet',
#    'time',
#    'building',
#    'to',
#    'a',
#    'climax',
#    'that',
#    "'s",
#    'scarcely',
#    'a',
#    'surprise',
#    'by',
#    'the',
#    'time'],
#   2),
#  (['an', 'interesting', 'character', 'to', 'begin', 'with'], 3),
#  (['enough', 'puff'], 2),
#  (['like', 'the', 'work', 'of', 'someone'], 3),
#  (['of',
#    'the',
#    'saddest',
#    'action',
#    'hero',
#    'performances',
#    'ever',
#    'witnessed'],
#   1),
#  (['a',
#    'movie',
#    'that',
#    'will',
#    'stimulate',
#    'hours',
#    'of',
#    'post',
#    'viewing',
#    'discussion',
#    ',',
#    'if',
#    'only',
#    'to',
#    'be',
#    'reminded',
#    'of',
#    'who',
#    'did',
#    'what',
#    'to',
#    'whom',
#    'and',
#    'why'],
#   3),
#  (['supporting', 'ones'], 2),
#  (['back', 'the', 'springboard'], 2),
#  (['reaffirms',
#    'life',
#    'as',
#    'it',
#    'looks',
#    'in',
#    'the',
#    'face',
#    'of',
#    'death'],
#   3),
#  (['scathing', 'portrayal'], 2),
#  (['tackles',
#    'the',
#    'difficult',
#    'subject',
#    'of',
#    'grief',
#    'and',
#    'loss',
#    'with',
#    'such',
#    'life-embracing',
#    'spirit',
#    'that',
#    'the',
#    'theme',
#    'does',
#    "n't",
#    'drag',
#    'an',
#    'audience',
#    'down',
#    '.'],
#   3),
#  (['seeing',
#    'as',
#    'the',
#    'film',
#    'lacks',
#    'momentum',
#    'and',
#    'its',
#    'position',
#    'remains',
#    'mostly',
#    'undeterminable',
#    ',',
#    'the',
#    'director',
#    "'s",
#    'experiment',
#    'is',
#    'a',
#    'successful',
#    'one',
#    '.'],
#   3),
#  (['of', 'the', 'previous', 'two'], 3),
#  (["'s", 'a', 'lot', 'to', 'recommend', 'read', 'my', 'lips', '.'], 2),
#  (['does',
#    "n't",
#    'even',
#    'try',
#    'for',
#    'the',
#    'greatness',
#    'that',
#    'happy',
#    'together',
#    'shoots',
#    'for',
#    '-lrb-',
#    'and',
#    'misses',
#    '-rrb-'],
#   1),
#  (['angel',
#    'presents',
#    'events',
#    'partly',
#    'from',
#    'the',
#    'perspective',
#    'of',
#    'aurelie',
#    'and',
#    'christelle',
#    ',',
#    'and',
#    'infuses',
#    'the',
#    'film',
#    'with',
#    'the',
#    'sensibility',
#    'of',
#    'a',
#    'particularly',
#    'nightmarish',
#    'fairytale',
#    '.'],
#   3),
#  (['injuries', ','], 2),
#  (['the',
#    'mark',
#    'of',
#    'a',
#    'respectable',
#    'summer',
#    'blockbuster',
#    'is',
#    'one',
#    'of',
#    'two',
#    'things',
#    ':',
#    'unadulterated',
#    'thrills',
#    'or',
#    'genuine',
#    'laughs',
#    '.'],
#   4),
#  (['colgate', 'u.'], 2),
#  (['-lrb-', 'time', 'out', 'and', 'human', 'resources', '-rrb-'], 2),
#  (['no', 'idea', 'of', 'it', 'is', 'serious'], 1),
#  (['the', 'chasm', 'of', 'knowledge'], 2),
#  (['brutally'], 2),
#  (['precisely'], 3),
#  (['regarding', 'life'], 2),
#  (['facet'], 2),
#  (['eventually',
#    'gets',
#    'around',
#    'to',
#    'its',
#    'real',
#    'emotional',
#    'business',
#    ',',
#    'striking',
#    'deep',
#    'chords',
#    'of',
#    'sadness',
#    '.'],
#   3),
#  (['non-porn'], 2),
#  (['the', 'upbeat', 'ending', 'feels', 'like', 'a', 'copout'], 1),
#  (['the', 'passive-aggressive', 'psychology', 'of', 'co-dependence'], 1),
#  (['crystal', 'and', 'de', 'niro', '-rrb-'], 3),
#  (['of', 'lowbrow', 'comedy'], 2),
#  (['is',
#    'one',
#    'of',
#    'those',
#    'films',
#    'that',
#    'requires',
#    'the',
#    'enemy',
#    'to',
#    'never',
#    'shoot',
#    'straight',
#    '.'],
#   1),
#  (['to', '1970s', 'action', 'films'], 2),
#  (['her',
#    'lover',
#    'mario',
#    'cavaradossi',
#    ',',
#    'and',
#    'ruggero',
#    'as',
#    'the',
#    'villainous',
#    ',',
#    'lecherous',
#    'police',
#    'chief',
#    'scarpia'],
#   2),
#  (['is', 'not', 'even', 'half', 'the', 'interest', '.'], 1),
#  (['begins',
#    'to',
#    'seem',
#    'as',
#    'long',
#    'as',
#    'the',
#    'two',
#    'year',
#    'affair',
#    'which',
#    'is',
#    'its',
#    'subject'],
#   1),
#  (['that', 'makes', 'michael', 'jordan', 'jealous'], 1),
#  (['to', 'think'], 2),
#  (['director', 'julie', 'taymor'], 2),
#  (['it', 'tries', 'too', 'hard'], 2),
#  (['nutty', ',', 'consistently', 'funny', '.'], 3),
#  (['not', 'only', 'is', 'it', 'hokey'], 1),
#  ([',',
#    'laborious',
#    'whine',
#    ',',
#    'the',
#    'bellyaching',
#    'of',
#    'a',
#    'paranoid',
#    'and',
#    'unlikable',
#    'man',
#    '.'],
#   2),
#  (['eddie', 'murphy', 'and', 'owen', 'wilson'], 2),
#  (['so',
#    'often',
#    'plague',
#    'films',
#    'dealing',
#    'with',
#    'the',
#    'mentally',
#    'ill'],
#   2),
#  (['festival', 'film'], 2),
#  (['odd', 'and'], 1),
#  (['of', 'the', 'kafkaesque'], 2),
#  (['does',
#    'not',
#    'achieve',
#    'the',
#    'kind',
#    'of',
#    'dramatic',
#    'unity',
#    'that',
#    'transports',
#    'you'],
#   1),
#  (['characteristically'], 2),
#  (['director-writer', 'bille', 'august', '...'], 2),
#  (['inventive', 'moments'], 3),
#  (["'s", 'one', 'of', 'the', 'worst', 'of', 'the', 'entire', 'franchise', '.'],
#   0),
#  (['undeniably', 'moving', 'film'], 4),
#  (['filmmaker', 'tian', 'zhuangzhuang'], 2),
#  (['excite',
#    'that',
#    'it',
#    'churns',
#    'up',
#    'not',
#    'one',
#    'but',
#    'two',
#    'flagrantly',
#    'fake',
#    'thunderstorms',
#    'to',
#    'underscore',
#    'the',
#    'action'],
#   2),
#  (['diapers'], 2),
#  (['in',
#    'this',
#    'junk',
#    'that',
#    "'s",
#    'tv',
#    'sitcom',
#    'material',
#    'at',
#    'best'],
#   1),
#  (['of', 'mindless', 'pace', 'in', 'collision'], 1),
#  (['equally', 'great', 'robin', 'williams', 'performance'], 4),
#  (['mean-spirited', 'and'], 1),
#  (['surrounding', 'us'], 3),
#  (['a',
#    'screen',
#    'adaptation',
#    'of',
#    'evans',
#    "'",
#    'saga',
#    'of',
#    'hollywood',
#    'excess'],
#   2),
#  (['of', 'destruction'], 1),
#  (['the', 'whole', 'show'], 2),
#  (['its', 'electronic', 'expression'], 2),
#  (['engulfed'], 2),
#  (['baader-meinhof'], 2),
#  (['great', 'pleasure'], 4),
#  (['mean-spirited'], 1),
#  (['jolts'], 2),
#  (['fails',
#    'to',
#    'portray',
#    'its',
#    'literarily',
#    'talented',
#    'and',
#    'notorious',
#    'subject',
#    'as',
#    'anything',
#    'much',
#    'more',
#    'than',
#    'a',
#    'dirty',
#    'old',
#    'man'],
#   1),
#  (['comes', 'across', ',', 'rather', 'unintentionally'], 2),
#  (['retread',
#    ',',
#    'hobbled',
#    'by',
#    'half-baked',
#    'setups',
#    'and',
#    'sluggish',
#    'pacing',
#    '.'],
#   1),
#  (['a', 'rambling', 'examination', 'of', 'american', 'gun', 'culture'], 2),
#  (['the', 'glum'], 2),
#  (['their', 'tormentor', 'deserved'], 2),
#  (['just',
#    'what',
#    'this',
#    'strenuously',
#    'unconventional',
#    'movie',
#    'is',
#    'supposed',
#    'to',
#    'be'],
#   3),
#  (['to', 'make', 'it'], 2),
#  (['one', 'visual', 'marvel'], 3),
#  (['is', 'playing', 'the', 'obvious', 'game'], 2),
#  (['of', 'runteldat'], 2),
#  (['aptly'], 3),
#  (['suspend', 'your', 'disbelief', 'here', 'and', 'now', ',', 'or'], 2),
#  (['martin',
#    "'s",
#    'deterioration',
#    'and',
#    'barbara',
#    "'s",
#    'sadness',
#    '--',
#    'and',
#    ','],
#   2),
#  (['just',
#    'sits',
#    'there',
#    'like',
#    'a',
#    'side',
#    'dish',
#    'no',
#    'one',
#    'ordered',
#    '.'],
#   1),
#  (['for', 'adults'], 2),
#  (['even',
#    'before',
#    'it',
#    'builds',
#    'up',
#    'to',
#    'its',
#    'insanely',
#    'staged',
#    'ballroom',
#    'scene',
#    ',',
#    'in',
#    'which',
#    '3000',
#    'actors',
#    'appear',
#    'in',
#    'full',
#    'regalia',
#    ',',
#    'it',
#    "'s",
#    'waltzed',
#    'itself',
#    'into',
#    'the',
#    'art',
#    'film',
#    'pantheon',
#    '.'],
#   3),
#  (['a',
#    'period',
#    'story',
#    'about',
#    'a',
#    'catholic',
#    'boy',
#    'who',
#    'tries',
#    'to',
#    'help',
#    'a',
#    'jewish',
#    'friend',
#    'get',
#    'into',
#    'heaven',
#    'by',
#    'sending',
#    'the',
#    'audience',
#    'straight',
#    'to',
#    'hell',
#    '.'],
#   0),
#  (['as',
#    'improbable',
#    'as',
#    'this',
#    'premise',
#    'may',
#    'seem',
#    ',',
#    'abbass',
#    "'s",
#    'understated',
#    ',',
#    'shining',
#    'performance',
#    'offers',
#    'us',
#    'the',
#    'sense',
#    'that',
#    'on',
#    'some',
#    'elemental',
#    'level',
#    ',',
#    'lilia',
#    'deeply',
#    'wants',
#    'to',
#    'break',
#    'free',
#    'of',
#    'her',
#    'old',
#    'life',
#    '.'],
#   4),
#  (['from', 'the', 'perspective', 'of', 'aurelie', 'and', 'christelle'], 2),
#  (['some',
#    'people',
#    'want',
#    'the',
#    "ol'",
#    'ball-and-chain',
#    'and',
#    'then',
#    'there',
#    'are',
#    'those',
#    'who',
#    'just',
#    'want',
#    'the',
#    'ball',
#    'and',
#    'chain'],
#   2),
#  (['dark'], 2),
#  (['school', 'swimming'], 2),
#  (['the',
#    'film',
#    'is',
#    'so',
#    'busy',
#    'making',
#    'reference',
#    'to',
#    'other',
#    'films',
#    'and',
#    'trying',
#    'to',
#    'be',
#    'other',
#    'films',
#    'that',
#    'it',
#    'fails',
#    'to',
#    'have',
#    'a',
#    'heart',
#    ',',
#    'mind',
#    'or',
#    'humor',
#    'of',
#    'its',
#    'own',
#    '.'],
#   0),
#  (['that', 'it', "'s", 'a', 'brazenly', 'misguided', 'project'], 0),
#  (['gentle', 'war'], 2),
#  (['to', 'pure', 'disney'], 2),
#  (['its', 'cast', ',', 'its', 'cuisine'], 2),
#  (['your', 'slave', 'for', 'a', 'year'], 2),
#  (['low', ',', 'very', 'low', ','], 1),
#  (['a', '`', 'bad', "'", 'police'], 2),
#  (['an', 'unexpected', 'window'], 2),
#  (['did',
#    ',',
#    'with',
#    'a',
#    'serious',
#    'minded',
#    'patience',
#    ',',
#    'respect',
#    'and',
#    'affection'],
#   3),
#  ([',',
#    'yet',
#    'not',
#    'as',
#    'hilariously',
#    'raunchy',
#    'as',
#    'south',
#    'park',
#    ',',
#    'this',
#    'strangely',
#    'schizo',
#    'cartoon',
#    'seems',
#    'suited',
#    'neither',
#    'to',
#    'kids',
#    'or',
#    'adults',
#    '.'],
#   1),
#  (['a', 'sentimental', 'mess'], 1),
#  (['the', 'way', 'we', 'were'], 2),
#  (['day-old', 'shelf'], 2),
#  (['confined', 'and'], 1),
#  (['overly', 'long', 'and'], 2),
#  (['some', 'of', 'the', 'computer', 'animation', 'is', 'handsome', ','], 3),
#  (['more', 'than', 'merely', 'a', 'holocaust', 'movie'], 3),
#  (['at', 'the', 'mercy', 'of', 'its', 'inventiveness'], 1),
#  (['this', 'much', 'imagination'], 3),
#  (['the',
#    'screenplay',
#    'never',
#    'lets',
#    'us',
#    'forget',
#    'that',
#    'bourne',
#    'was',
#    'once',
#    'an',
#    'amoral',
#    'assassin',
#    'just',
#    'like',
#    'the',
#    'ones',
#    'who',
#    'are',
#    'pursuing',
#    'him',
#    '...',
#    'there',
#    'is',
#    'never',
#    'really',
#    'a',
#    'true',
#    '``',
#    'us',
#    "''",
#    'versus',
#    '``',
#    'them',
#    "''"],
#   3),
#  (['painful'], 1),
#  ([',', 'flat', 'dialogue'], 1),
#  (['at',
#    'the',
#    'very',
#    'special',
#    'type',
#    'of',
#    'badness',
#    'that',
#    'is',
#    'deuces',
#    'wild'],
#   1),
#  (['new', 'zealand', 'coming-of-age', 'movie'], 3),
#  (['her', 'love', 'depraved', 'leads', 'meet', ','], 2),
#  (['you',
#    "'re",
#    'really',
#    'renting',
#    'this',
#    'you',
#    "'re",
#    'not',
#    'interested',
#    'in',
#    'discretion',
#    'in',
#    'your',
#    'entertainment',
#    'choices'],
#   1),
#  (['mantra'], 2),
#  (['the',
#    'film',
#    'gets',
#    'close',
#    'to',
#    'the',
#    'chimps',
#    'the',
#    'same',
#    'way',
#    'goodall',
#    'did',
#    ',',
#    'with',
#    'a',
#    'serious',
#    'minded',
#    'patience',
#    ',',
#    'respect',
#    'and',
#    'affection',
#    '.'],
#   3),
#  (['aimless', 'hodgepodge'], 1),
#  (['with', 'a', 'large', 'dose', 'of', 'painkillers'], 1),
#  (['without', 'merit'], 1),
#  (['to', 'lowly', 'studio', 'hack'], 1),
#  (['into', 'the', 'abyss'], 2),
#  (['of', 'a', 'sitcom', 'apparatus'], 2),
#  (['its', 'fusty', 'squareness'], 1),
#  (['sentimental', 'oh-those-wacky-brits', 'genre'], 2),
#  (['than', 'a', '`', 'direct-to-video', "'", 'release'], 1),
#  (['texture', 'and', 'realism'], 3),
#  (["'s", 'one', 'of', 'the', 'worst', 'of', 'the', 'entire', 'franchise'], 0),
#  (['farce', ','], 1),
#  (['for',
#    'two',
#    'directors',
#    'with',
#    'far',
#    'less',
#    'endearing',
#    'disabilities'],
#   1),
#  (['falters'], 1),
#  (['like', 'a', 'chocolate', 'milk'], 2),
#  (['elaborate', 'choreography'], 3),
#  (['an', 'incredibly', 'irritating', 'comedy'], 0),
#  (['a',
#    'film',
#    'that',
#    "'s",
#    'not',
#    'merely',
#    'about',
#    'kicking',
#    'undead',
#    '\\*\\*\\*'],
#   3),
#  (['world', 'dichotomy'], 2),
#  (['a',
#    'delightful',
#    ',',
#    'if',
#    'minor',
#    ',',
#    'pastry',
#    'of',
#    'a',
#    'movie',
#    '.'],
#   4),
#  (['after', '9\\/11'], 2),
#  (['a', 'more', 'immediate', 'mystery', 'in', 'the', 'present'], 2),
#  (['watching', 'it', 'now'], 2),
#  (['ultimately', 'pointless'], 0),
#  (['the', 'problem', 'with', 'all', 'of', 'this'], 1),
#  (['is', 'also', 'somewhat', 'shallow', 'and', 'art-conscious'], 1),
#  (['an',
#    'uneven',
#    'mix',
#    'of',
#    'dark',
#    'satire',
#    'and',
#    'childhood',
#    'awakening'],
#   3),
#  (['niche'], 2),
#  (['more', 'than', 'capable', 'of', 'rewarding', 'them'], 3),
#  ([',', 'the', 'eye', 'candy', 'here', 'lacks', 'considerable', 'brio', '.'],
#   1),
#  (['i', 'just', 'saw', 'this', 'movie', '...'], 2),
#  (['the', '``', 'queen', "''", 'and'], 2),
#  (['by',
#    'the',
#    'end',
#    'of',
#    'the',
#    'movie',
#    ',',
#    'you',
#    "'re",
#    'definitely',
#    'convinced',
#    'that',
#    'these',
#    'women',
#    'are',
#    'spectacular',
#    '.'],
#   3),
#  (['this', 'date-night', 'diversion'], 1),
#  (['been', 'acted', 'out'], 1),
#  (['you', "'ll", 'feel', 'too', 'happy', 'to', 'argue', 'much'], 3),
#  (['a', 'satisfying', 'complete', 'picture'], 3),
#  (['its',
#    'almost',
#    'too-spectacular',
#    'coastal',
#    'setting',
#    'distracts',
#    'slightly',
#    'from',
#    'an',
#    'eccentric',
#    'and',
#    'good-naturedly',
#    'aimless',
#    'story',
#    '.'],
#   3),
#  (['of',
#    'those',
#    'terrific',
#    'documentaries',
#    'that',
#    'collect',
#    'a',
#    'bunch',
#    'of',
#    'people',
#    'who',
#    'are',
#    'enthusiastic',
#    'about',
#    'something',
#    'and',
#    'then'],
#   3),
#  (['the', 'one', 'thing'], 2),
#  (['the',
#    'durable',
#    'best',
#    'seller',
#    'smart',
#    'women',
#    ',',
#    'foolish',
#    'choices',
#    'for',
#    'advice'],
#   2),
#  (['although',
#    'it',
#    'lacks',
#    'the',
#    'detail',
#    'of',
#    'the',
#    'book',
#    ',',
#    'the',
#    'film',
#    'does',
#    'pack',
#    'some',
#    'serious',
#    'suspense',
#    '.'],
#   3),
#  (['provoked', 'to', 'intolerable', 'levels'], 1),
#  (['is', 'nothing'], 2),
#  (['alternately', 'hilarious', 'and', 'sad', ','], 2),
#  (['the', 'abyss'], 1),
#  (['teeth-clenching'], 3),
#  (['singer'], 2),
#  (['it',
#    "'s",
#    'a',
#    'boring',
#    'movie',
#    'about',
#    'a',
#    'boring',
#    'man',
#    ',',
#    'made',
#    'watchable',
#    'by',
#    'a',
#    'bravura',
#    'performance',
#    'from',
#    'a',
#    'consummate',
#    'actor',
#    'incapable',
#    'of',
#    'being',
#    'boring',
#    '.'],
#   3),
#  (['an',
#    'impossible',
#    'spot',
#    'because',
#    'his',
#    'character',
#    "'s",
#    'deceptions',
#    'ultimately',
#    'undo',
#    'him',
#    'and',
#    'the',
#    'believability',
#    'of',
#    'the',
#    'entire',
#    'scenario'],
#   2),
#  (['is', 'flavorless'], 0),
#  (['like', 'an', 'extreme', 'action-packed', 'film'], 3),
#  (['its', 'own', 'tangled', 'plot'], 2),
#  (['long-lived', 'friendships'], 3),
#  (['who',
#    'do',
#    "n't",
#    'entirely',
#    '`',
#    'get',
#    "'",
#    'godard',
#    "'s",
#    'distinctive',
#    'discourse'],
#   2),
#  (['carries',
#    'the',
#    'day',
#    'with',
#    'impeccable',
#    'comic',
#    'timing',
#    ',',
#    'raffish',
#    'charm',
#    'and',
#    'piercing',
#    'intellect',
#    '.'],
#   3),
#  (['retina'], 2),
#  (['with',
#    'all',
#    'the',
#    'dysfunctional',
#    'family',
#    'dynamics',
#    'one',
#    'could',
#    'wish',
#    'for'],
#   3),
#  (['in', '`', 'the', 'ring'], 2),
#  (['that', "'s", 'ok'], 2),
#  (['a', 'taut', ',', 'sobering', 'film'], 4),
#  (['bertrand'], 2),
#  (['wastes',
#    'its',
#    'time',
#    'on',
#    'mood',
#    'rather',
#    'than',
#    'riding',
#    'with',
#    'the',
#    'inherent',
#    'absurdity',
#    'of',
#    'ganesh',
#    "'s",
#    'rise',
#    'up',
#    'the',
#    'social',
#    'ladder',
#    '.'],
#   1),
#  (['the', 'potency'], 2),
#  (['that',
#    'for',
#    'the',
#    'uninitiated',
#    'plays',
#    'better',
#    'on',
#    'video',
#    'with',
#    'the',
#    'sound'],
#   2),
#  (['a', 'truck', ',', 'preferably', 'a', 'semi'], 2),
#  (['standard', 'guns'], 2),
#  (['is',
#    'a',
#    'subversive',
#    'element',
#    'to',
#    'this',
#    'disney',
#    'cartoon',
#    ',',
#    'providing',
#    'unexpected',
#    'fizzability'],
#   2),
#  (['spears'], 2),
#  (['view', 'a', 'movie', 'as', 'harrowing'], 2),
#  (['build',
#    'some',
#    'robots',
#    ',',
#    'haul',
#    "'em",
#    'to',
#    'the',
#    'theatre',
#    'with',
#    'you',
#    'for',
#    'the',
#    'late',
#    'show',
#    ',',
#    'and',
#    'put',
#    'on',
#    'your',
#    'own',
#    'mystery',
#    'science',
#    'theatre',
#    '3000',
#    'tribute',
#    'to',
#    'what',
#    'is',
#    'almost',
#    'certainly',
#    'going',
#    'to',
#    'go',
#    'down',
#    'as',
#    'the',
#    'worst',
#    '--',
#    'and',
#    'only',
#    '--',
#    'killer',
#    'website',
#    'movie',
#    'of',
#    'this',
#    'or',
#    'any',
#    'other',
#    'year'],
#   0),
#  (['to', 'receive', 'a', 'un', 'inspector'], 2),
#  (['with',
#    'only',
#    'weak',
#    'claims',
#    'to',
#    'surrealism',
#    'and',
#    'black',
#    'comedy'],
#   1),
#  (['to',
#    'create',
#    'characters',
#    'who',
#    'are',
#    'sweet',
#    'and',
#    'believable',
#    ',',
#    'and',
#    'are',
#    'defeated',
#    'by',
#    'a',
#    'screenplay',
#    'that',
#    'forces',
#    'them',
#    'into',
#    'bizarre',
#    ',',
#    'implausible',
#    'behavior'],
#   1),
#  (['final', '-lrb-', 'restored', '-rrb-', 'third'], 2),
#  (['runyon'], 2),
#  (['the', 'movie', 'passes', 'inspection'], 3),
#  (['a', 'movie', 'as', 'you'], 2),
#  (['it',
#    "'s",
#    'not',
#    'particularly',
#    'subtle',
#    '...',
#    'however',
#    ',',
#    'it',
#    'still',
#    'manages',
#    'to',
#    'build',
#    'to',
#    'a',
#    'terrifying',
#    ',',
#    'if',
#    'obvious',
#    ',',
#    'conclusion'],
#   2),
#  (['juni', '-lrb-', 'sabara', '-rrb-', 'cortez'], 2),
#  (['literary', 'mystery', 'story'], 2),
#  (['whether', 'you', "'re", 'into', 'rap', 'or', 'not'], 2),
#  (['it',
#    'does',
#    "n't",
#    'even',
#    'try',
#    'for',
#    'the',
#    'greatness',
#    'that',
#    'happy',
#    'together',
#    'shoots',
#    'for',
#    '-lrb-',
#    'and',
#    'misses',
#    '-rrb-'],
#   1),
#  (['the', 'humanizing', 'stuff'], 2),
#  (['never', 'quite', 'gets', 'there'], 1),
#  (['the', 'jackal', ',', 'the', 'french', 'connection'], 2),
#  (['repulse', 'any', 'generation', 'of', 'its', 'fans'], 2),
#  (['as', 'for', 'children'], 2),
#  (['nice', 'to', 'see', 'piscopo', 'again', 'after', 'all', 'these', 'years'],
#   3),
#  (['concubine'], 2),
#  (['and', 'not', 'always', 'for', 'the', 'better'], 1),
#  (["'s", 'not', '.'], 2),
#  (['with', 'dreams', ',', 'visions'], 2),
#  (['us', 'to', 'forget', 'that', 'they', 'are', 'actually', 'movie', 'folk'],
#   2),
#  (['tries-so-hard-to-be-cool', '``', 'clockstoppers'], 1),
#  (['his',
#    'collaborators',
#    "'",
#    'symbolic',
#    'images',
#    'with',
#    'his',
#    'words',
#    ','],
#   3),
#  (['possess',
#    ',',
#    'with',
#    'or',
#    'without',
#    'access',
#    'to',
#    'the',
#    'ballot',
#    'box'],
#   2),
#  (['bespeaks'], 2),
#  (['sparkles',
#    'in',
#    'its',
#    'deft',
#    'portrait',
#    'of',
#    'tinseltown',
#    "'s",
#    'seasoned',
#    'veterans',
#    'of',
#    'gossip',
#    ',',
#    'wealth',
#    ','],
#   4),
#  (['a', 'better', 'travelogue'], 2),
#  (['the',
#    '`',
#    'true',
#    'story',
#    "'",
#    'by',
#    'which',
#    'all',
#    'the',
#    'queen',
#    "'s",
#    'men',
#    'is',
#    'allegedly',
#    '``',
#    'inspired',
#    "''",
#    'was',
#    'a',
#    'lot',
#    'funnier',
#    'and',
#    'more',
#    'deftly',
#    'enacted',
#    'than',
#    'what',
#    "'s",
#    'been',
#    'cobbled',
#    'together',
#    'onscreen'],
#   1),
#  (['revitalize'], 3),
#  (['has', 'felt', ',', 'or', 'will', 'feel', 'someday'], 2),
#  (['inauthentic'], 0),
#  (['orange', 'prison', 'jumpsuit'], 2),
#  (['wise', 'and', 'surprisingly', 'inoffensive'], 2),
#  (['vibrant', 'introduction'], 3),
#  (['look',
#    'back',
#    'at',
#    'what',
#    'it',
#    'was',
#    'to',
#    'be',
#    'iranian-american',
#    'in',
#    '1979'],
#   2),
#  (['the', 'relationships'], 2),
#  (['london'], 2),
#  (['with', 'its', 'subjects', 'a', 'little', 'longer'], 2),
#  (['furious'], 1),
#  (['reopens'], 2),
#  (['a', 'straight', 'guy', 'has', 'to', 'dress', 'up', 'in', 'drag'], 2),
#  ([',',
#    'they',
#    'are',
#    'pitted',
#    'against',
#    'shimmering',
#    'cinematography',
#    'that',
#    'lends',
#    'the',
#    'setting',
#    'the',
#    'ethereal',
#    'beauty',
#    'of',
#    'an',
#    'asian',
#    'landscape',
#    'painting',
#    '.'],
#   4),
#  (['one-sided', ','], 1),
#  (['olympia', ',', 'wash.', ','], 2),
#  (['likable',
#    ',',
#    'but',
#    'just',
#    'as',
#    'often',
#    'it',
#    "'s",
#    'meandering',
#    ',',
#    'low',
#    'on',
#    'energy',
#    ',',
#    'and',
#    'too',
#    'eager',
#    'to',
#    'be',
#    'quirky',
#    'at',
#    'moments',
#    'when',
#    'a',
#    'little',
#    'old-fashioned',
#    'storytelling',
#    'would',
#    'come',
#    'in',
#    'handy',
#    '.'],
#   1),
#  (['stupid',
#    'americans',
#    'will',
#    'get',
#    'a',
#    'kick',
#    'out',
#    'of',
#    'goofy',
#    'brits',
#    'with',
#    'cute',
#    'accents',
#    'performing',
#    'ages-old',
#    'slapstick',
#    'and',
#    'unfunny',
#    'tricks'],
#   1),
#  (['like', 'a', 'book', 'report'], 1),
#  (['called', 'iranian'], 2),
#  (['thank', 'goodness', 'for', 'this', 'signpost'], 2),
#  (['cultural', 'messages'], 2),
#  (['has',
#    'made',
#    'a',
#    'movie',
#    'that',
#    'will',
#    'leave',
#    'you',
#    'wondering',
#    'about',
#    'the',
#    'characters',
#    "'",
#    'lives',
#    'after',
#    'the',
#    'clever',
#    'credits',
#    'roll',
#    '.'],
#   3),
#  (['a',
#    'battle',
#    'of',
#    'witlessness',
#    'between',
#    'a',
#    'not-so-bright',
#    'mother',
#    'and',
#    'daughter',
#    'and',
#    'an',
#    'even',
#    'less',
#    'capable',
#    'trio',
#    'of',
#    'criminals'],
#   1),
#  (['there',
#    "'s",
#    'something',
#    'about',
#    'mary',
#    'and',
#    'both',
#    'american',
#    'pie',
#    'movies'],
#   3),
#  (['ben', 'stiller', "'s", 'zoolander'], 2),
#  (['the', 'real', 'charm'], 3),
#  (['compelling', 'investigation'], 3),
#  (['and', ',', 'in', 'the', 'end'], 2),
#  (['far',
#    'less',
#    'about',
#    'the',
#    'horrifying',
#    'historical',
#    'reality',
#    'than',
#    'about',
#    'the',
#    'filmmaker',
#    "'s",
#    'characteristic',
#    'style'],
#   2),
#  (['schmaltzy', 'and', 'clumsily'], 0),
#  (['belongs'], 2),
#  (['as', 'analgesic', 'balm', 'for', 'overstimulated', 'minds'], 2),
#  (['much', 'to', 'hang', 'a', 'soap', 'opera', 'on'], 2),
#  (['ham-fisted'], 1),
#  (['by',
#    'halfway',
#    'through',
#    'this',
#    'picture',
#    'i',
#    'was',
#    'beginning',
#    'to',
#    'hate',
#    'it',
#    ',',
#    'and',
#    ',',
#    'of',
#    'course'],
#   0),
#  (['soap', 'opera', 'antics'], 2),
#  (['in', 'advancing', 'this', 'vision'], 2),
#  (['idealism', 'american', 'moviemaking', 'ever'], 2),
#  (['the', 'impressively', 'discreet', 'filmmakers'], 3),
#  (['the', 'picture', 'runs', 'a', 'mere', '84', 'minutes'], 2),
#  (['see',
#    'scratch',
#    'for',
#    'a',
#    'lesson',
#    'in',
#    'scratching',
#    ',',
#    'but',
#    ',',
#    'most',
#    'of',
#    'all',
#    ',',
#    'see',
#    'it',
#    'for',
#    'the',
#    'passion'],
#   2),
#  (['carefully', 'choreographed'], 3),
#  (['behind', 'the', 'little', 'mermaid'], 2),
#  (['will', 'likely', 'prefer', 'to', 'keep', 'on', 'watching'], 3),
#  (['to', 'do', 'a', 'little', 'fleeing', 'of', 'its', 'own'], 1),
#  (['of', 'creative', 'belly', 'laughs'], 4),
#  (['donovan', '...', 'squanders', 'his', 'main', 'asset', ','], 1),
#  (["'ve",
#    'been',
#    'nice',
#    'if',
#    'the',
#    'screenwriters',
#    'had',
#    'trusted',
#    'audiences',
#    'to',
#    'understand',
#    'a',
#    'complex',
#    'story',
#    ',',
#    'and',
#    'left',
#    'off',
#    'the',
#    'film',
#    "'s",
#    'predictable',
#    'denouement',
#    '.'],
#   2),
#  (['though',
#    'its',
#    'rather',
#    'routine',
#    'script',
#    'is',
#    'loaded',
#    'with',
#    'familiar',
#    'situations'],
#   1),
#  (['their', '70s'], 2),
#  (['out-of-kilter'], 1),
#  (['egoyan',
#    "'s",
#    'work',
#    'often',
#    'elegantly',
#    'considers',
#    'various',
#    'levels',
#    'of',
#    'reality',
#    'and',
#    'uses',
#    'shifting',
#    'points',
#    'of',
#    'view'],
#   4),
#  (['the', 'entire', 'point', 'of', 'a', 'shaggy', 'dog', 'story', ','], 2),
#  (['messing', 'around'], 2),
#  (['tell', 'who', 'is', 'chasing', 'who', 'or', 'why'], 2),
#  (['just',
#    'enough',
#    'sweet',
#    'and',
#    'traditional',
#    'romantic',
#    'comedy',
#    'to',
#    'counter',
#    'the',
#    'crudity'],
#   3),
#  (['most', 'sparkling'], 4),
#  (['of', '`', 'let', "'s", 'get', 'this', 'thing', 'over', 'with', "'"], 2),
#  (['can',
#    'watch',
#    ',',
#    'giggle',
#    'and',
#    'get',
#    'an',
#    'adrenaline',
#    'boost',
#    'without',
#    'feeling',
#    'like',
#    'you',
#    "'ve",
#    'completely',
# ...
#    'interested',
#    'in',
#    'nothing',
#    'more',
#    'than',
#    'sucking',
#    'you',
#    'in',
#    '...',
#    'and',
#    'making',
#    'you',
#    'sweat'],
#   3),
#  (['the',
#    'pianist',
#    '-lrb-',
#    'is',
#    '-rrb-',
#    'a',
#    'supremely',
#    'hopeful',
#    'cautionary',
#    'tale',
#    'of',
#    'war',
#    "'s",
#    'madness',
#    'remembered',
#    'that',
#    'we',
#    ',',
#    'today',
#    ',',
#    'can',
#    'prevent',
#    'its',
#    'tragic',
#    'waste',
#    'of',
#    'life',
#    '.'],
#   4),
#  (['just', 'that'], 2),
#  (['wickedly', 'sick', 'and', 'twisted', 'humor'], 3),
#  (['frustrates', 'and'], 1),
#  (['simple', ',', 'poignant', 'and', 'leavened', 'with', 'humor'], 3),
#  (['shtick', 'and'], 2),
#  (['felt', 'and'], 2),
#  (['broder',
#    "'s",
#    'screenplay',
#    'is',
#    'shallow',
#    ',',
#    'offensive',
#    'and',
#    'redundant',
#    ',',
#    'with',
#    'pitifully',
#    'few',
#    'real',
#    'laughs',
#    '.'],
#   1),
#  (['extraordinary', 'dramatic', 'experience', '.'], 4),
#  (['well', 'worthwhile'], 4),
#  (['it',
#    'transporting',
#    'is',
#    'that',
#    'it',
#    "'s",
#    'also',
#    'one',
#    'of',
#    'the',
#    'smartest'],
#   4),
#  (['suspects',
#    'that',
#    'craven',
#    'endorses',
#    'they',
#    'simply',
#    'because',
#    'this',
#    'movie',
#    'makes',
#    'his',
#    'own',
#    'look',
#    'much',
#    'better',
#    'by',
#    'comparison'],
#   1),
#  (['seem',
#    'all',
#    'that',
#    'profound',
#    ',',
#    'at',
#    'least',
#    'by',
#    'way',
#    'of',
#    'what',
#    'can',
#    'be',
#    'gleaned',
#    'from',
#    'this',
#    'three-hour',
#    'endurance',
#    'test',
#    'built',
#    'around',
#    'an',
#    'hour',
#    "'s",
#    'worth',
#    'of',
#    'actual',
#    'material'],
#   1),
#  (['twin'], 2),
#  (['a.e.w.',
#    'mason',
#    "'s",
#    'story',
#    'to',
#    'suit',
#    'the',
#    'sensibilities',
#    'of',
#    'a',
#    'young',
#    'american',
#    ',',
#    'a',
#    'decision',
#    'that',
#    'plucks',
#    '``',
#    'the',
#    'four',
#    'feathers',
#    "''",
#    'bare'],
#   1),
#  (['the', 'two', 'and', 'a', 'half', 'mark'], 2),
#  (['very', 'tense'], 2),
#  (['by', 'cgi', 'aliens', 'and', 'super', 'heroes'], 2),
#  (['to',
#    'blast',
#    'even',
#    'the',
#    'smallest',
#    'sensitivities',
#    'from',
#    'the',
#    'romance',
#    'with',
#    'his',
#    'clamorous',
#    'approach'],
#   1),
#  (['eh'], 1),
#  (['ultimately', 'expresses', 'empathy', 'for', 'bartleby', "'s", 'pain'], 2),
#  (['little', 'more', 'than', 'a', 'well-mounted', 'history', 'lesson'], 1),
#  (['awe'], 2),
#  (['the', '1960', 'version'], 2),
#  (['while', 'puerile', 'men', 'dominate', 'the', 'story'], 2),
#  (['miss',
#    'wonton',
#    'floats',
#    'beyond',
#    'reality',
#    'with',
#    'a',
#    'certain',
#    'degree',
#    'of',
#    'wit',
#    'and',
#    'dignity'],
#   3),
#  (['none',
#    'of',
#    'this',
#    'is',
#    'half',
#    'as',
#    'moving',
#    'as',
#    'the',
#    'filmmakers',
#    'seem',
#    'to',
#    'think',
#    '.'],
#   1),
#  (['his', 'sister'], 2),
#  (['imogen', 'kimmel'], 2),
#  (['be', 'ahead', 'of', 'the', 'plot', 'at', 'all', 'times'], 2),
#  (['put', 'pillowcases', 'over', 'their', 'heads'], 2),
#  (['its', 'terrific', 'performances'], 4),
#  (['a', 'new', 'scene', ','], 2),
#  (['makes', 'social', 'commentary', 'more', 'palatable'], 2),
#  (['is', 'all', 'over', 'the', 'place', ','], 2),
#  (['for', 'every', 'taste'], 3),
#  (['no', 'matter', 'what'], 2),
#  (['girl-meets-girl', 'love', 'story'], 2),
#  (['on',
#    'not',
#    'giving',
#    'up',
#    'on',
#    'dreams',
#    'when',
#    'you',
#    "'re",
#    'a',
#    'struggling',
#    'nobody'],
#   2),
#  (['someone', 'made', 'off', 'with', 'your', 'wallet'], 1),
#  (['hyped', 'to', 'be', 'because', 'it', 'plays', 'everything', 'too', 'safe'],
#   2),
#  (['sucks', ',', 'but'], 1),
#  (['it', "'s", 'not', 'too', 'much', 'of', 'anything', '.'], 1),
#  (['knowing', 'horror', 'films'], 2),
#  (['overpowered'], 2),
#  (['sex', 'comedy'], 2),
#  (['just',
#    'another',
#    'disjointed',
#    ',',
#    'fairly',
#    'predictable',
#    'psychological',
#    'thriller',
#    '.'],
#   0),
#  (['a', 'pasolini', 'film', 'without', 'passion', 'or', 'politics'], 1),
#  (['almost',
#    'expected',
#    'there',
#    'to',
#    'be',
#    'a',
#    'collection',
#    'taken',
#    'for',
#    'the',
#    'comedian',
#    'at',
#    'the',
#    'end',
#    'of',
#    'the',
#    'show',
#    '.'],
#   2),
#  (['further',
#    'sad',
#    'evidence',
#    'that',
#    'tom',
#    'tykwer',
#    ',',
#    'director',
#    'of',
#    'the',
#    'resonant',
#    'and',
#    'sense-spinning',
#    'run',
#    'lola',
#    'run',
#    ',',
#    'has',
#    'turned',
#    'out',
#    'to',
#    'be',
#    'a',
#    'one-trick',
#    'pony'],
#   0),
#  (['a',
#    'worthwhile',
#    'documentary',
#    ',',
#    'whether',
#    'you',
#    "'re",
#    'into',
#    'rap',
#    'or',
#    'not',
#    ',',
#    'even',
#    'if',
#    'it',
#    'may',
#    'still',
#    'leave',
#    'you',
#    'wanting',
#    'more',
#    'answers',
#    'as',
#    'the',
#    'credits',
#    'roll',
#    '.'],
#   3),
#  (["'s", 'all', 'true', '.'], 2),
#  (['its', 'footage'], 2),
#  (['last',
#    'orders',
#    'will',
#    'touch',
#    'the',
#    'heart',
#    'of',
#    'anyone',
#    'old',
#    'enough',
#    'to',
#    'have',
#    'earned',
#    'a',
#    '50-year',
#    'friendship'],
#   3),
#  (['of',
#    'an',
#    'artist',
#    'who',
#    'is',
#    'simply',
#    'tired',
#    '--',
#    'of',
#    'fighting',
#    'the',
#    'same',
#    'fights',
#    ',',
#    'of',
#    'putting',
#    'the',
#    'weight',
#    'of',
#    'the',
#    'world',
#    'on',
#    'his',
#    'shoulders',
#    ',',
#    'of',
#    'playing',
#    'with',
#    'narrative',
#    'form'],
#   1),
#  (['it',
#    'just',
#    'did',
#    "n't",
#    'mean',
#    'much',
#    'to',
#    'me',
#    'and',
#    'played',
#    'too',
#    'skewed',
#    'to',
#    'ever',
#    'get',
#    'a',
#    'hold',
#    'on'],
#   2),
#  (['like', 'kubrick'], 2),
#  (['people',
#    'may',
#    'be',
#    'wondering',
#    'what',
#    'all',
#    'that',
#    'jazz',
#    'was',
#    'about',
#    '``',
#    'chicago',
#    "''",
#    'in',
#    '2002',
#    '.'],
#   1),
#  (['at', 'play'], 2),
#  (['bumper'], 2),
#  (['a', 'lovely', 'trifle'], 3),
#  (['it',
#    'is',
#    'were',
#    'it',
#    'not',
#    'for',
#    'the',
#    'striking',
#    ',',
#    'quietly',
#    'vulnerable',
#    'personality',
#    'of',
#    'ms.',
#    'ambrose'],
#   3),
#  (["'s",
#    'better',
#    'to',
#    'go',
#    'in',
#    'knowing',
#    'full',
#    'well',
#    'what',
#    "'s",
#    'going',
#    'to',
#    'happen',
#    ',',
#    'but',
#    'willing',
#    'to',
#    'let',
#    'the',
#    'earnestness',
#    'of',
#    'its',
#    'execution',
#    'and',
#    'skill',
#    'of',
#    'its',
#    'cast',
#    'take',
#    'you',
#    'down',
#    'a',
#    'familiar',
#    'road',
#    'with',
#    'a',
#    'few',
#    'twists'],
#   2),
#  (['a', 'sentimental', 'mess', 'that', 'never', 'rings', 'true', '.'], 0),
#  (['with', 'their', 'own', 'eyes'], 2),
#  (['utterly', 'charming'], 3),
#  (['poof'], 2),
#  (['smaller', 'scenes'], 2),
#  (['french', 'revolution'], 2),
#  (['fans', 'of', 'british', 'cinema'], 2),
#  (['weaving'], 2),
#  (['an',
#    'inexperienced',
#    'director',
#    ',',
#    'mehta',
#    'has',
#    'much',
#    'to',
#    'learn',
#    '.'],
#   1),
#  (['an', 'unflappable', 'air', 'of', 'decadent', 'urbanity'], 2),
#  (['desolate', 'air'], 2),
#  (['something'], 2),
#  (['one',
#    'of',
#    'those',
#    'art',
#    'house',
#    'films',
#    'that',
#    'makes',
#    'you',
#    'feel',
#    'like',
#    'you',
#    "'re",
#    'watching',
#    'an',
#    'iceberg',
#    'melt',
#    '--',
#    'only'],
#   1),
#  (['is',
#    'a',
#    'disaster',
#    'of',
#    'a',
#    'story',
#    ',',
#    'full',
#    'of',
#    'holes',
#    'and',
#    'completely',
#    'lacking',
#    'in',
#    'chills'],
#   0),
#  (['has',
#    'one',
#    'of',
#    'the',
#    'most',
#    'moronic',
#    'screenplays',
#    'of',
#    'the',
#    'year',
#    ',',
#    'full',
#    'of',
#    'holes',
#    'that',
#    'will',
#    'be',
#    'obvious',
#    'even',
#    'to',
#    'those',
#    'who',
#    'are',
#    "n't",
#    'looking',
#    'for',
#    'them',
#    '.'],
#   0),
#  (['whose', 'orbits', 'will', 'inevitably'], 2),
#  (['put', 'it', 'together', 'yourself'], 2),
#  (['each', 'one'], 2),
#  (['adam', 'sandler', 'assault'], 1),
#  (['look',
#    'behind',
#    'the',
#    'curtain',
#    'that',
#    'separates',
#    'comics',
#    'from',
#    'the',
#    'people',
#    'laughing',
#    'in',
#    'the',
#    'crowd'],
#   2),
#  (['as',
#    'if',
#    'you',
#    'were',
#    'paying',
#    'dues',
#    'for',
#    'good',
#    'books',
#    'unread',
#    ',',
#    'fine',
#    'music',
#    'never',
#    'heard'],
#   2),
#  (['since', 'the', 'last', 'waltz'], 2),
#  (['benefits', 'from', 'several', 'funny', 'moments'], 3),
#  (['trouble', 'every', 'day', 'is', 'a', 'plodding', 'mess', '.'], 0),
#  (['as', 'emotionally', 'grand'], 3),
#  (['to', 'feel', 'contradictory', 'things'], 2),
#  (['on', 'one', 'continuum'], 2),
#  (['as',
#    'long',
#    'as',
#    'you',
#    "'re",
#    'wearing',
#    'the',
#    'somewhat',
#    'cumbersome',
#    '3d',
#    'goggles'],
#   1),
#  (['by', 'the', 'importance', 'of', 'being', 'earnest'], 2),
#  (['owe'], 2),
#  (['as', 'your', 'abc', "'s"], 2),
#  (['riviera'], 2),
#  ([',', 'but', 'because', 'of', 'the', 'startling', 'intimacy'], 3),
#  (['desperate', 'violinist', 'wife'], 2),
#  (['``', 'what', 'really', 'happened', '?', "''"], 2),
#  (['angela', 'gheorghiu', ','], 2),
#  (['has',
#    'about',
#    '3\\/4th',
#    'the',
#    'fun',
#    'of',
#    'its',
#    'spry',
#    '2001',
#    'predecessor',
#    '--',
#    'but',
#    'it',
#    "'s",
#    'a',
#    'rushed',
#    ',',
#    'slapdash',
#    ',',
#    'sequel-for-the-sake',
#    '-',
#    'of-a-sequel',
#    'with',
#    'less',
#    'than',
#    'half',
#    'the',
#    'plot',
#    'and',
#    'ingenuity'],
#   0),
#  (['but',
#    'even',
#    'while',
#    'his',
#    'characters',
#    'are',
#    'acting',
#    'horribly',
#    ',',
#    'he',
#    'is',
#    'always',
#    'sympathetic',
#    '.'],
#   3),
#  (['captures',
#    'the',
#    'unsettled',
#    'tenor',
#    'of',
#    'that',
#    'post',
#    '9-11',
#    'period',
#    'far',
#    'better'],
#   3),
#  (['predictable', 'plot'], 1),
#  (['to', 'suddenly', 'transpose', 'himself', 'into', 'another', 'character'],
#   2),
#  (['like', 'the', 'full', 'monty'], 2),
#  (['an',
#    'unencouraging',
#    'threefold',
#    'expansion',
#    'on',
#    'the',
#    'former',
#    'mtv',
#    'series',
#    ',',
#    'accompanying',
#    'the',
#    'stunt-hungry',
#    'dimwits',
#    'in',
#    'a',
#    'random',
#    'series',
#    'of',
#    'collected',
#    'gags',
#    ',',
#    'pranks',
#    ',',
#    'pratfalls',
#    ',',
#    'dares',
#    ',',
#    'injuries',
#    ',',
#    'etc.',
#    '.'],
#   1),
#  (['provide'], 2),
#  (['emerges', 'from', 'the', 'shadow', 'of', 'ellis', "'", 'book'], 2),
#  ([',', 'menacing', 'atmosphere'], 2),
#  (['a',
#    'cellophane-pop',
#    'remake',
#    'of',
#    'the',
#    'punk',
#    'classic',
#    'ladies',
#    'and',
#    'gentlemen',
#    ',',
#    'the',
#    'fabulous',
#    'stains',
#    '...'],
#   1),
#  (['implodes'], 1),
#  (['millions', 'of', 'eager', 'fans'], 4),
#  (['characterizes', 'better', 'hip-hop', 'clips', 'and'], 2),
#  (['a', 'solid', 'cast'], 4),
#  (['murderer'], 1),
#  (['a', 'funny', 'and', 'touching', 'film'], 4),
#  (['to',
#    're-create',
#    'the',
#    'excitement',
#    'of',
#    'such',
#    "'50s",
#    'flicks',
#    'as',
#    'jules',
#    'verne',
#    "'s",
#    "'",
#    '20,000',
#    'leagues',
#    'under',
#    'the',
#    'sea',
#    "'",
#    'and',
#    'the',
#    'george',
#    'pal',
#    'version',
#    'of',
#    'h.g.',
#    'wells',
#    "'",
#    '`',
#    'the',
#    'time',
#    'machine'],
#   3),
#  (['chiefly', 'inspires', 'you', 'to', 'drive', 'a', 'little', 'faster'], 2),
#  (['see',
#    '``',
#    'blue',
#    'crush',
#    "''",
#    'is',
#    'the',
#    'phenomenal',
#    ',',
#    'water-born',
#    'cinematography',
#    'by',
#    'david',
#    'hennings'],
#   4),
#  (['lacks',
#    'balance',
#    '...',
#    'and',
#    'fails',
#    'to',
#    'put',
#    'the',
#    'struggle',
#    'into',
#    'meaningful',
#    'historical',
#    'context'],
#   1),
#  (['from',
#    'a',
#    'vampire',
#    'pic',
#    'than',
#    'a',
#    'few',
#    'shrieky',
#    'special',
#    'effects'],
#   2),
#  (['an',
#    'overripe',
#    'episode',
#    'of',
#    'tv',
#    "'s",
#    'dawson',
#    "'s",
#    'creek',
#    'and',
#    'a',
#    'recycled',
#    'and',
#    'dumbed-down',
#    'version',
#    'of',
#    'love',
#    'story'],
#   0),
#  (['every', 'five', 'minutes'], 2),
#  (['of', 'the', 'country'], 2),
#  (['jumps',
#    'to',
#    'the',
#    'head',
#    'of',
#    'the',
#    'class',
#    'of',
#    'women',
#    "'s",
#    'films'],
#   4),
#  (['goddammit'], 0),
#  (['in', 'the', 'transporter'], 2),
#  (['a', 'seriously', 'intended', 'movie'], 3),
#  (['this', 'premise'], 2),
#  (['the', 'astute', 'direction', 'of', 'cardoso'], 3),
#  (['derailed', 'by', 'a', 'failure'], 2),
#  (['pack', 'raw', 'dough', 'in', 'my', 'ears'], 0),
#  (['hardy', 'group'], 3),
#  (['an',
#    'awkwardly',
#    'garish',
#    'showcase',
#    'that',
#    'diverges',
#    'from',
#    'anything'],
#   1),
#  (['no', 'new', 'plot', 'conceptions', 'or', 'environmental', 'changes'], 1),
#  (['who',
#    'knows',
#    ',',
#    'but',
#    'it',
#    'works',
#    'under',
#    'the',
#    'direction',
#    'of',
#    'kevin',
#    'reynolds',
#    '.'],
#   3),
#  (['videotape'], 2),
#  (['the',
#    'intellectual',
#    'and',
#    'emotional',
#    'pedigree',
#    'of',
#    'your',
#    'date'],
#   2),
#  (['with', 'its', 'lackadaisical', 'plotting', 'and', 'mindless', 'action'],
#   1),
#  (['all-out', 'villain'], 2),
#  (['sleeping', 'dogs', 'lie'], 2),
#  (['film', 'i'], 2),
#  (['a', 'subtle', ',', 'poignant', 'picture'], 3),
#  (['has', 'this', 'franchise', 'ever', 'run', 'out', 'of', 'gas', '.'], 2),
#  (['does',
#    'a',
#    'fine',
#    'job',
#    'contrasting',
#    'the',
#    'sleekness',
#    'of',
#    'the',
#    'film',
#    "'s",
#    'present',
#    'with',
#    'the',
#    'playful',
#    'paranoia',
#    'of',
#    'the',
#    'film',
#    "'s",
#    'past'],
#   4),
#  (['bears',
#    'a',
#    'grievous',
#    'but',
#    'obscure',
#    'complaint',
#    'against',
#    'fathers',
#    ',',
#    'and'],
#   2),
#  (['gasp'], 3),
#  (['the', 'three', 'leads', 'produce', 'adequate', 'performances'], 2),
#  (['gargantuan', 'leaps', 'of', 'faith', 'just'], 2),
#  (['stunt', 'cars'], 2),
#  (['full', 'experience'], 2),
#  (['performances', 'and', 'direction'], 2),
#  (['were', 'written', 'by', 'somebody', 'else', '.'], 2),
#  (['we',
#    "'ve",
#    'seen',
#    'it',
#    'all',
#    'before',
#    'in',
#    'one',
#    'form',
#    'or',
#    'another',
#    ',',
#    'but',
#    'director',
#    'hoffman',
#    ',',
#    'with',
#    'great',
#    'help',
#    'from',
#    'kevin',
#    'kline',
#    ',',
#    'makes',
#    'us',
#    'care',
#    'about',
#    'this',
#    'latest',
#    'reincarnation',
#    'of',
#    'the',
#    'world',
#    "'s",
#    'greatest',
#    'teacher',
#    '.'],
#   3),
#  (['`',
#    'possession',
#    ',',
#    "'",
#    'based',
#    'on',
#    'the',
#    'book',
#    'by',
#    'a.s.',
#    'byatt',
#    ',',
#    'demands',
#    'that',
#    'labute',
#    'deal',
#    'with',
#    'the',
#    'subject',
#    'of',
#    'love',
#    'head-on',
#    ';',
#    'trading',
#    'in',
#    'his',
#    'cynicism',
#    'for',
#    'reverence',
#    'and',
#    'a',
#    'little',
#    'wit'],
#   3),
#  (["'ll",
#    'laugh',
#    'for',
#    'not',
#    'quite',
#    'and',
#    'hour',
#    'and',
#    'a',
#    'half',
#    ',',
#    'but',
#    'come',
#    'out',
#    'feeling',
#    'strangely',
#    'unsatisfied'],
#   1),
#  (['hoods'], 2),
#  (['an', 'uneasy', 'blend'], 1),
#  ([',',
#    'murder',
#    'hits',
#    'and',
#    'generally',
#    'sustains',
#    'a',
#    'higher',
#    'plateau',
#    'with',
#    'bullock',
#    "'s",
#    'memorable',
#    'first',
#    'interrogation',
#    'of',
#    'gosling',
#    '.'],
#   3),
#  (['the', 'size', 'of', 'a', 'house'], 2),
#  (["'s", 'often', 'overwritten'], 1),
#  (['karmen'], 2),
#  (['a', 'tour', 'de'], 2),
#  (['while', 'solondz', 'tries', 'and', 'tries', 'hard'], 2),
#  (['sibling',
#    'reconciliation',
#    'with',
#    'flashes',
#    'of',
#    'warmth',
#    'and',
#    'gentle',
#    'humor'],
#   3),
#  (['italian', 'guys'], 2),
#  (['as', 'steamy', 'as'], 2),
#  (['big', 'way'], 2),
#  (['worst', 'titles'], 0),
#  (['to', 'watch', 'on', 'video', 'at', 'home'], 2),
#  (["'s",
#    'always',
#    'these',
#    'rehashes',
#    'to',
#    'feed',
#    'to',
#    'the',
#    'younger',
#    'generations'],
#   3),
#  (['flow', 'through', 'the', 'hollywood', 'pipeline'], 2),
#  (['the', 'animated', 'sequences'], 2),
#  (['billing'], 2),
#  (['roger', 'swanson'], 2),
#  (['in',
#    'a',
#    'ridiculous',
#    'wig',
#    'no',
#    'respectable',
#    'halloween',
#    'costume',
#    'shop',
#    'would',
#    'ever',
#    'try',
#    'to',
#    'sell'],
#   1),
#  (['living-room'], 2),
#  (['freeing', 'them', 'from', 'artefact'], 2),
#  (['guns', ','], 2),
#  ...]

# %% [markdown]
# <H2>Stemming</H2>
# Stemming was run below.  Stemming normalizing words without affixes (prefixes and suffixes) so as to improve training and classification.  The idea is that if we only use the roots of words, training will work better as there will likely be more instances of a given root to use for training than all the variations with different prefixes and suffixes.
#
# Our performance did go up a couple of percentage points on the test dataset, so stemming is helping.

# %%
nltk.PorterStemmer()
stemmedLines = [([stemmer.stem(s) for s in line[0]],line[1]) for line in lines]
runClassification(stemmedLines,3000)
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# Time to train and evaluate: 65.3899998665
# TrainSetResults
# Accuracy: 0.631333333333
# F-measure [0]: 0.43321299639
# F-measure [1]: 0.484918793503
# F-measure [2]: 0.743357829282
# F-measure [3]: 0.457425742574
# F-measure [4]: 0.504792332268
# Precision [0]: 0.434782608696
# Precision [1]: 0.607558139535
# Precision [2]: 0.652281746032
# Precision [3]: 0.614361702128
# Precision [4]: 0.626984126984
# Recall [0]: 0.431654676259
# Recall [1]: 0.403474903475
# Recall [2]: 0.863994743758
# Recall [3]: 0.364353312303
# Recall [4]: 0.422459893048
# TestSet Results
# Evaluating NaiveBayesClassifier results...
# Accuracy: 0.49
# F-measure [0]: 0.117647058824
# F-measure [1]: 0.222222222222
# F-measure [2]: 0.626086956522
# F-measure [3]: 0.314285714286
# F-measure [4]: 0.551724137931
# Precision [0]: 0.166666666667
# Precision [1]: 0.315789473684
# Precision [2]: 0.507042253521
# Precision [3]: 0.478260869565
# Precision [4]: 0.8
# Recall [0]: 0.0909090909091
# Recall [1]: 0.171428571429
# Recall [2]: 0.818181818182
# Recall [3]: 0.234042553191
# Recall [4]: 0.421052631579

# %% [markdown]
# <H2>Different Stemmer Algorithm</H2>
# Here we try a different stemmer to see if returns better results with our testdata.  Results were the same.  Granted the test size is small, so perhaps in bigger training sets we see a difference.  But In any case it seems likely that the choice of stemmers would not matter much.

# %%
stemmer = nltk.LancasterStemmer()
stemmedlines = [([stemmer.stem(s) for s in line[0]],line[1]) for line in lines]
runClassification(stemmedLines, 3000)
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# Time to train and evaluate: 64.6100001335
# TrainSetResults
# Accuracy: 0.631333333333
# F-measure [0]: 0.43321299639
# F-measure [1]: 0.484918793503
# F-measure [2]: 0.743357829282
# F-measure [3]: 0.457425742574
# F-measure [4]: 0.504792332268
# Precision [0]: 0.434782608696
# Precision [1]: 0.607558139535
# Precision [2]: 0.652281746032
# Precision [3]: 0.614361702128
# Precision [4]: 0.626984126984
# Recall [0]: 0.431654676259
# Recall [1]: 0.403474903475
# Recall [2]: 0.863994743758
# Recall [3]: 0.364353312303
# Recall [4]: 0.422459893048
# TestSet Results
# Evaluating NaiveBayesClassifier results...
# Accuracy: 0.49
# F-measure [0]: 0.117647058824
# F-measure [1]: 0.222222222222
# F-measure [2]: 0.626086956522
# F-measure [3]: 0.314285714286
# F-measure [4]: 0.551724137931
# Precision [0]: 0.166666666667
# Precision [1]: 0.315789473684
# Precision [2]: 0.507042253521
# Precision [3]: 0.478260869565
# Precision [4]: 0.8
# Recall [0]: 0.0909090909091
# Recall [1]: 0.171428571429
# Recall [2]: 0.818181818182
# Recall [3]: 0.234042553191
# Recall [4]: 0.421052631579

# %% [markdown]
# <H2>Toooo Slow</H2>
# So now that we trained with some very small samples of the dataset (156k lines is the total), lets try a little bit bigger size to train with: 10k.  Unfortunately this too 12 times longer with only slightly more than 3 times the size of the data to train. Performance did improve, and no doubt the performance would improve more with larger data, if we could spend the computation time.  But with the full training set about 15 times bigger, and the growth not linear, this method of classification looks poor.  Therefore we try the SciKit libraries (with some NLTK libraries) in the other file)

# %%
runClassification(stemmedLines, 10000)
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# Time to train and evaluate: 672.63499999
# TrainSetResults
# Accuracy: 0.6226
# F-measure [0]: 0.43254376931
# F-measure [1]: 0.474363215349
# F-measure [2]: 0.736106256554
# F-measure [3]: 0.478085351788
# F-measure [4]: 0.471663619744
# Precision [0]: 0.426829268293
# Precision [1]: 0.58674304419
# Precision [2]: 0.651004636785
# Precision [3]: 0.617734724292
# Precision [4]: 0.544303797468
# Recall [0]: 0.438413361169
# Recall [1]: 0.398112159911
# Recall [2]: 0.846803377563
# Recall [3]: 0.389934148636
# Recall [4]: 0.416129032258
# TestSet Results
# Evaluating NaiveBayesClassifier results...
# Accuracy: 0.51
# F-measure [0]: 0.235294117647
# F-measure [1]: 0.328358208955
# F-measure [2]: 0.676056338028
# F-measure [3]: 0.4
# F-measure [4]: 0.0869565217391
# Precision [0]: 0.222222222222
# Precision [1]: 0.34375
# Precision [2]: 0.595041322314
# Precision [3]: 0.551724137931
# Precision [4]: 0.111111111111
# Recall [0]: 0.25
# Recall [1]: 0.314285714286
# Recall [2]: 0.782608695652
# Recall [3]: 0.313725490196
# Recall [4]: 0.0714285714286

# %%
# rawLines = [line[0] for line in lines]
# bigrams = sentim_analyzer.bigram_collocation_feats(rawLines, min_freq=40)

# %%
def sentimentPipeLineBigram(lines):
    sentimAnalyzer = SentimentAnalyzer()
    all_words_neg = sentimAnalyzer.all_words([mark_negation(line) for line in lines])
    unigramFeats = sentimAnalyzer.unigram_word_feats(all_words_neg, min_freq=4)
    sentimAnalyzer.add_feat_extractor(extract_unigram_feats, unigrams=unigramFeats)
    rawLines = [line[0] for line in lines]
    bigrams = sentimAnalyzer.bigram_collocation_feats(rawLines, min_freq=10)
    sentimAnalyzer.add_feat_extractor(extract_bigram_feats, bigrams=bigrams)
    return(sentimAnalyzer)

# %%
def runClassificationBigram(lines, size):
    trainLines = lines[:size]
    testLines = lines[size:size+200]
    startTime = time.time()
    
    sentimAnalyzer = sentimentPipeLineBigram(trainLines)     
    trainSet = sentimAnalyzer.apply_features(trainLines)
    testSet = sentimAnalyzer.apply_features(testLines)    
    trainer = NaiveBayesClassifier.train;
    classifier = sentimAnalyzer.train(trainer, trainSet)    
    
    evaluated = sentimAnalyzer.evaluate(trainSet)
    endTime = time.time()    
    print 'Time to train and evaluate: ' + str(endTime - startTime)    
    print 'TrainSetResults'
    for key,value in sorted(evaluated.items()):
        print('{0}: {1}'.format(key, value))

    print 'TestSet Results'
    evaluated = sentimAnalyzer.evaluate(testSet)
    for key,value in sorted(evaluated.items()):
        print('{0}: {1}'.format(key, value))

# %%
runClassificationBigram(stemmedLines, 3000)
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# Time to train and evaluate: 82.756000042
# TrainSetResults
# Accuracy: 0.631
# F-measure [0]: 0.450909090909
# F-measure [1]: 0.487917146145
# F-measure [2]: 0.739290780142
# F-measure [3]: 0.46368159204
# F-measure [4]: 0.509202453988
# Precision [0]: 0.455882352941
# Precision [1]: 0.603988603989
# Precision [2]: 0.650524213679
# Precision [3]: 0.628032345013
# Precision [4]: 0.597122302158
# Recall [0]: 0.446043165468
# Recall [1]: 0.409266409266
# Recall [2]: 0.856110381078
# Recall [3]: 0.367507886435
# Recall [4]: 0.44385026738
# TestSet Results
# Evaluating NaiveBayesClassifier results...
# Accuracy: 0.475
# F-measure [0]: 0.210526315789
# F-measure [1]: 0.22641509434
# F-measure [2]: 0.606060606061
# F-measure [3]: 0.268656716418
# F-measure [4]: 0.533333333333
# Precision [0]: 0.25
# Precision [1]: 0.333333333333
# Precision [2]: 0.48951048951
# Precision [3]: 0.45
# Precision [4]: 0.727272727273
# Recall [0]: 0.181818181818
# Recall [1]: 0.171428571429
# Recall [2]: 0.795454545455
# Recall [3]: 0.191489361702
# Recall [4]: 0.421052631579

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

sentences = dfTxt.Phrase
sentiments = dfTxt.Sentiment
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\todddesktop\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
